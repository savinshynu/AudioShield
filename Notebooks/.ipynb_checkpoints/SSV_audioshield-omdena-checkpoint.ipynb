# %% [markdown]
# ### Developer: Savin Shynu Varghese
#
# ## Audio Deepfake detection
# ### Outline
# 1. Exploratory data analysis and visualization
# 2. Preprocessing
# 3. Model development
# 4. Model Evaluation
#
# ###  Exploratory data analysis and visualization
#
# The dataset for this work is stored in the dagshub repository: "Omdena/BangladeshChapter_Audiosheild".
# We can mount the data directly from the dagshub into google collab, but working in this manner is slow. For the purpose of this notebook, I have collected the data from the dagshub repo and stored locally on my laptop for easier processing.
#
# Data from the dagshub can be mounted in google collab this way:
#
# 1. install dagshub: **%pip install -q dagshub**
#
# 2. Mounting the repository :
#
#     **import dagshub.colab**
#
#     **repo=dagshub.colab.login()**
#
# 2. Mount path: **path=dagshub.storage.mount('Omdena/BangladeshChapter_AudioShield')**

# %% [markdown]
# ### Data Exploration.
# Let's explore the dataset to understand the content in terms of the raw data and their annotations.

# %%
# data directory
data_dir = '/Users/savin/Omdena-Projects/Audioshield/data_train/'

# %ls /Users/savin/Omdena-Projects/Audioshield/data_train/
# Out:
# ASVspoof2019_LA_asv_protocols/ ASVspoof2019_LA_eval/
# ASVspoof2019_LA_asv_scores/    ASVspoof2019_LA_train/
# ASVspoof2019_LA_cm_protocols/  README.LA.txt
# ASVspoof2019_LA_dev/

# %% [markdown]
# As we can see here, there are 3 folders containing the training, development(validation) and evaluation (test) datasets. The ASVspoof2019_LA_cm_protocols folder contains the metadata labelings of the each dataset.

# %%
# %ls /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_cm_protocols
# Out:
# ASVspoof2019.LA.cm.dev.trl.txt    ASVspoof2019.LA.cm.train.trn.txt
# ASVspoof2019.LA.cm.eval.trl.txt

# %%
#Listing the contents of the training file in the protocol folder
# %cat /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.train.trn.txt
# Out:
# LA_0079 LA_T_1138215 - - bonafide
# LA_0079 LA_T_1271820 - - bonafide
# LA_0079 LA_T_1272637 - - bonafide
# LA_0079 LA_T_1276960 - - bonafide
# LA_0079 LA_T_1341447 - - bonafide
# LA_0079 LA_T_1363611 - - bonafide
# LA_0079 LA_T_1596451 - - bonafide
# LA_0079 LA_T_1608170 - - bonafide
# LA_0079 LA_T_1684951 - - bonafide
# LA_0079 LA_T_1699801 - - bonafide
# LA_0079 LA_T_1703395 - - bonafide
# LA_0079 LA_T_1736342 - - bonafide
# LA_0079 LA_T_1779188 - - bonafide
# LA_0079 LA_T_1786825 - - bonafide
# LA_0079 LA_T_1787246 - - bonafide
# LA_0079 LA_T_1905558 - - bonafide
# LA_0079 LA_T_2205687 - - bonafide
# LA_0079 LA_T_2220901 - - bonafide
# LA_0079 LA_T_2361751 - - bonafide
# LA_0079 LA_T_2373806 - - bonafide
# LA_0079 LA_T_2417641 - - bonafide
# LA_0079 LA_T_2520083 - - bonafide
# LA_0079 LA_T_2562689 - - bonafide
# LA_0079 LA_T_2564579 - - bonafide
# LA_0079 LA_T_2732709 - - bonafide
# LA_0079 LA_T_2759900 - - bonafide
# LA_0079 LA_T_2838981 - - bonafide
# LA_0079 LA_T_2873890 - - bonafide
# LA_0079 LA_T_2938316 - - bonafide
# LA_0079 LA_T_3131990 - - bonafide
# LA_0079 LA_T_3141223 - - bonafide
# LA_0079 LA_T_3167734 - - bonafide
# LA_0079 LA_T_3187715 - - bonafide
# LA_0079 LA_T_3215578 - - bonafide
# LA_0079 LA_T_3247389 - - bonafide
# LA_0079 LA_T_3346004 - - bonafide
# LA_0079 LA_T_3441957 - - bonafide
# LA_0079 LA_T_3561136 - - bonafide
# LA_0079 LA_T_3576775 - - bonafide
# LA_0079 LA_T_3580508 - - bonafide
# LA_0079 LA_T_3635733 - - bonafide
# LA_0079 LA_T_3636245 - - bonafide
# LA_0079 LA_T_3810183 - - bonafide
# LA_0079 LA_T_3849267 - - bonafide
# LA_0079 LA_T_3995089 - - bonafide
# LA_0079 LA_T_3999087 - - bonafide
# LA_0079 LA_T_3999267 - - bonafide
# LA_0079 LA_T_4053835 - - bonafide
# LA_0079 LA_T_4118798 - - bonafide
# LA_0079 LA_T_4155454 - - bonafide
# LA_0079 LA_T_4179989 - - bonafide
# LA_0079 LA_T_4197307 - - bonafide
# LA_0079 LA_T_4237787 - - bonafide
# LA_0079 LA_T_4239283 - - bonafide
# LA_0079 LA_T_4244329 - - bonafide
# LA_0079 LA_T_4339311 - - bonafide
# LA_0079 LA_T_4362109 - - bonafide
# LA_0079 LA_T_4428691 - - bonafide
# LA_0079 LA_T_4752788 - - bonafide
# LA_0079 LA_T_4756464 - - bonafide
# LA_0079 LA_T_4822766 - - bonafide
# LA_0079 LA_T_5096578 - - bonafide
# LA_0079 LA_T_5161420 - - bonafide
# LA_0079 LA_T_5191549 - - bonafide
# LA_0079 LA_T_5337549 - - bonafide
# LA_0079 LA_T_5387852 - - bonafide
# LA_0079 LA_T_5521272 - - bonafide
# LA_0079 LA_T_5761909 - - bonafide
# LA_0079 LA_T_5777819 - - bonafide
# LA_0079 LA_T_5785306 - - bonafide
# LA_0079 LA_T_5954195 - - bonafide
# LA_0079 LA_T_6058143 - - bonafide
# LA_0079 LA_T_6074694 - - bonafide
# LA_0079 LA_T_6105178 - - bonafide
# LA_0079 LA_T_6200206 - - bonafide
# LA_0079 LA_T_6214695 - - bonafide
# LA_0079 LA_T_6324553 - - bonafide
# LA_0079 LA_T_6335714 - - bonafide
# LA_0079 LA_T_6370865 - - bonafide
# LA_0079 LA_T_6405980 - - bonafide
# LA_0079 LA_T_6426017 - - bonafide
# LA_0079 LA_T_6492747 - - bonafide
# LA_0079 LA_T_6618587 - - bonafide
# LA_0079 LA_T_6630946 - - bonafide
# LA_0079 LA_T_6721654 - - bonafide
# LA_0079 LA_T_6736628 - - bonafide
# LA_0079 LA_T_6768659 - - bonafide
# LA_0079 LA_T_6960204 - - bonafide
# LA_0079 LA_T_7122854 - - bonafide
# LA_0079 LA_T_7123800 - - bonafide
# LA_0079 LA_T_7248140 - - bonafide
# LA_0079 LA_T_7288400 - - bonafide
# LA_0079 LA_T_7397041 - - bonafide
# LA_0079 LA_T_7677120 - - bonafide
# LA_0079 LA_T_7737943 - - bonafide
# LA_0079 LA_T_7744923 - - bonafide
# LA_0079 LA_T_8115679 - - bonafide
# LA_0079 LA_T_8145267 - - bonafide
# LA_0079 LA_T_8324598 - - bonafide
# LA_0079 LA_T_8449978 - - bonafide
# LA_0079 LA_T_8458654 - - bonafide
# LA_0079 LA_T_8507928 - - bonafide
# LA_0079 LA_T_8638376 - - bonafide
# LA_0079 LA_T_8682959 - - bonafide
# LA_0079 LA_T_9107429 - - bonafide
# LA_0079 LA_T_9152126 - - bonafide
# LA_0079 LA_T_9188299 - - bonafide
# LA_0079 LA_T_9258514 - - bonafide
# LA_0079 LA_T_9341221 - - bonafide
# LA_0079 LA_T_9431341 - - bonafide
# LA_0079 LA_T_9437384 - - bonafide
# LA_0079 LA_T_9456128 - - bonafide
# LA_0079 LA_T_9488159 - - bonafide
# LA_0079 LA_T_9515789 - - bonafide
# LA_0079 LA_T_9526930 - - bonafide
# LA_0079 LA_T_9534983 - - bonafide
# LA_0079 LA_T_9543922 - - bonafide
# LA_0079 LA_T_9596913 - - bonafide
# LA_0079 LA_T_9669914 - - bonafide
# LA_0079 LA_T_9701712 - - bonafide
# LA_0079 LA_T_9789409 - - bonafide
# LA_0079 LA_T_9803720 - - bonafide
# LA_0079 LA_T_9874922 - - bonafide
# LA_0079 LA_T_9897034 - - bonafide
# LA_0079 LA_T_9905136 - - bonafide
# LA_0079 LA_T_9907603 - - bonafide
# LA_0079 LA_T_9926593 - - bonafide
# LA_0080 LA_T_1078395 - - bonafide
# LA_0080 LA_T_1257508 - - bonafide
# LA_0080 LA_T_1290428 - - bonafide
# LA_0080 LA_T_1373249 - - bonafide
# LA_0080 LA_T_1411980 - - bonafide
# LA_0080 LA_T_1455233 - - bonafide
# LA_0080 LA_T_1470659 - - bonafide
# LA_0080 LA_T_1511191 - - bonafide
# LA_0080 LA_T_1618831 - - bonafide
# LA_0080 LA_T_1625761 - - bonafide
# LA_0080 LA_T_1651877 - - bonafide
# LA_0080 LA_T_1702062 - - bonafide
# LA_0080 LA_T_1735385 - - bonafide
# LA_0080 LA_T_1795259 - - bonafide
# LA_0080 LA_T_1820456 - - bonafide
# LA_0080 LA_T_1909202 - - bonafide
# LA_0080 LA_T_2091969 - - bonafide
# LA_0080 LA_T_2335057 - - bonafide
# LA_0080 LA_T_2386039 - - bonafide
# LA_0080 LA_T_2407353 - - bonafide
# LA_0080 LA_T_2486958 - - bonafide
# LA_0080 LA_T_2610237 - - bonafide
# LA_0080 LA_T_2698001 - - bonafide
# LA_0080 LA_T_2737588 - - bonafide
# LA_0080 LA_T_2777160 - - bonafide
# LA_0080 LA_T_2801441 - - bonafide
# LA_0080 LA_T_2835258 - - bonafide
# LA_0080 LA_T_2848593 - - bonafide
# LA_0080 LA_T_2869730 - - bonafide
# LA_0080 LA_T_2992916 - - bonafide
# LA_0080 LA_T_3108269 - - bonafide
# LA_0080 LA_T_3121388 - - bonafide
# LA_0080 LA_T_3127213 - - bonafide
# LA_0080 LA_T_3315434 - - bonafide
# LA_0080 LA_T_3317496 - - bonafide
# LA_0080 LA_T_3387982 - - bonafide
# LA_0080 LA_T_3465801 - - bonafide
# LA_0080 LA_T_3505297 - - bonafide
# LA_0080 LA_T_3518487 - - bonafide
# LA_0080 LA_T_3555171 - - bonafide
# LA_0080 LA_T_3595333 - - bonafide
# LA_0080 LA_T_3626619 - - bonafide
# LA_0080 LA_T_3725354 - - bonafide
# LA_0080 LA_T_3772667 - - bonafide
# LA_0080 LA_T_3840528 - - bonafide
# LA_0080 LA_T_3877261 - - bonafide
# LA_0080 LA_T_4077869 - - bonafide
# LA_0080 LA_T_4104820 - - bonafide
# LA_0080 LA_T_4105004 - - bonafide
# LA_0080 LA_T_4111857 - - bonafide
# LA_0080 LA_T_4140258 - - bonafide
# LA_0080 LA_T_4176612 - - bonafide
# LA_0080 LA_T_4356490 - - bonafide
# LA_0080 LA_T_4369654 - - bonafide
# LA_0080 LA_T_4397800 - - bonafide
# LA_0080 LA_T_4584120 - - bonafide
# LA_0080 LA_T_4904277 - - bonafide
# LA_0080 LA_T_5052270 - - bonafide
# LA_0080 LA_T_5058278 - - bonafide
# LA_0080 LA_T_5064135 - - bonafide
# LA_0080 LA_T_5079307 - - bonafide
# LA_0080 LA_T_5100132 - - bonafide
# LA_0080 LA_T_5134869 - - bonafide
# LA_0080 LA_T_5180830 - - bonafide
# LA_0080 LA_T_5223695 - - bonafide
# LA_0080 LA_T_5250310 - - bonafide
# LA_0080 LA_T_5264471 - - bonafide
# LA_0080 LA_T_5266787 - - bonafide
# LA_0080 LA_T_5359998 - - bonafide
# LA_0080 LA_T_5399126 - - bonafide
# LA_0080 LA_T_5404480 - - bonafide
# LA_0080 LA_T_5774498 - - bonafide
# LA_0080 LA_T_5866595 - - bonafide
# LA_0080 LA_T_5891775 - - bonafide
# LA_0080 LA_T_5913109 - - bonafide
# LA_0080 LA_T_5994708 - - bonafide
# LA_0080 LA_T_6078217 - - bonafide
# LA_0080 LA_T_6093418 - - bonafide
# LA_0080 LA_T_6306026 - - bonafide
# LA_0080 LA_T_6328130 - - bonafide
# LA_0080 LA_T_6356279 - - bonafide
# LA_0080 LA_T_6462285 - - bonafide
# LA_0080 LA_T_6474082 - - bonafide
# LA_0080 LA_T_6631167 - - bonafide
# LA_0080 LA_T_6856715 - - bonafide
# LA_0080 LA_T_6957393 - - bonafide
# LA_0080 LA_T_7015765 - - bonafide
# LA_0080 LA_T_7020265 - - bonafide
# LA_0080 LA_T_7039518 - - bonafide
# LA_0080 LA_T_7090581 - - bonafide
# LA_0080 LA_T_7102200 - - bonafide
# LA_0080 LA_T_7201521 - - bonafide
# LA_0080 LA_T_7316655 - - bonafide
# LA_0080 LA_T_7402461 - - bonafide
# LA_0080 LA_T_7450091 - - bonafide
# LA_0080 LA_T_7483904 - - bonafide
# LA_0080 LA_T_7589094 - - bonafide
# LA_0080 LA_T_7797285 - - bonafide
# LA_0080 LA_T_7856471 - - bonafide
# LA_0080 LA_T_7905464 - - bonafide
# LA_0080 LA_T_7913619 - - bonafide
# LA_0080 LA_T_7939465 - - bonafide
# LA_0080 LA_T_7948400 - - bonafide
# LA_0080 LA_T_8035781 - - bonafide
# LA_0080 LA_T_8086364 - - bonafide
# LA_0080 LA_T_8227234 - - bonafide
# LA_0080 LA_T_8363647 - - bonafide
# LA_0080 LA_T_8421122 - - bonafide
# LA_0080 LA_T_8541274 - - bonafide
# LA_0080 LA_T_8647496 - - bonafide
# LA_0080 LA_T_8651042 - - bonafide
# LA_0080 LA_T_8665473 - - bonafide
# LA_0080 LA_T_8683526 - - bonafide
# LA_0080 LA_T_8721428 - - bonafide
# LA_0080 LA_T_8739453 - - bonafide
# LA_0080 LA_T_8853276 - - bonafide
# LA_0080 LA_T_8857843 - - bonafide
# LA_0080 LA_T_8936519 - - bonafide
# LA_0080 LA_T_8988036 - - bonafide
# LA_0080 LA_T_9102017 - - bonafide
# LA_0080 LA_T_9120168 - - bonafide
# LA_0080 LA_T_9242200 - - bonafide
# LA_0080 LA_T_9296432 - - bonafide
# LA_0080 LA_T_9392152 - - bonafide
# LA_0080 LA_T_9478659 - - bonafide
# LA_0080 LA_T_9628936 - - bonafide
# LA_0080 LA_T_9884044 - - bonafide
# LA_0081 LA_T_1151332 - - bonafide
# LA_0081 LA_T_1213624 - - bonafide
# LA_0081 LA_T_1397401 - - bonafide
# LA_0081 LA_T_1441999 - - bonafide
# LA_0081 LA_T_1450124 - - bonafide
# LA_0081 LA_T_1459702 - - bonafide
# LA_0081 LA_T_1590800 - - bonafide
# LA_0081 LA_T_1670486 - - bonafide
# LA_0081 LA_T_1888223 - - bonafide
# LA_0081 LA_T_2070410 - - bonafide
# LA_0081 LA_T_2085766 - - bonafide
# LA_0081 LA_T_2189044 - - bonafide
# LA_0081 LA_T_2256140 - - bonafide
# LA_0081 LA_T_2305882 - - bonafide
# LA_0081 LA_T_2500033 - - bonafide
# LA_0081 LA_T_2634789 - - bonafide
# LA_0081 LA_T_2774875 - - bonafide
# LA_0081 LA_T_2802034 - - bonafide
# LA_0081 LA_T_2866777 - - bonafide
# LA_0081 LA_T_2875055 - - bonafide
# LA_0081 LA_T_2888246 - - bonafide
# LA_0081 LA_T_2890940 - - bonafide
# LA_0081 LA_T_2945445 - - bonafide
# LA_0081 LA_T_3163159 - - bonafide
# LA_0081 LA_T_3331468 - - bonafide
# LA_0081 LA_T_3342439 - - bonafide
# LA_0081 LA_T_3477694 - - bonafide
# LA_0081 LA_T_3508642 - - bonafide
# LA_0081 LA_T_3570279 - - bonafide
# LA_0081 LA_T_3588899 - - bonafide
# LA_0081 LA_T_3971937 - - bonafide
# LA_0081 LA_T_4096254 - - bonafide
# LA_0081 LA_T_4170168 - - bonafide
# LA_0081 LA_T_4222512 - - bonafide
# LA_0081 LA_T_4292472 - - bonafide
# LA_0081 LA_T_4400269 - - bonafide
# LA_0081 LA_T_4451472 - - bonafide
# LA_0081 LA_T_4513430 - - bonafide
# LA_0081 LA_T_4657133 - - bonafide
# LA_0081 LA_T_4684802 - - bonafide
# LA_0081 LA_T_4901591 - - bonafide
# LA_0081 LA_T_4956729 - - bonafide
# LA_0081 LA_T_5123366 - - bonafide
# LA_0081 LA_T_5159753 - - bonafide
# LA_0081 LA_T_5192765 - - bonafide
# LA_0081 LA_T_5570263 - - bonafide
# LA_0081 LA_T_5592527 - - bonafide
# LA_0081 LA_T_5638559 - - bonafide
# LA_0081 LA_T_5639776 - - bonafide
# LA_0081 LA_T_5777134 - - bonafide
# LA_0081 LA_T_5801784 - - bonafide
# LA_0081 LA_T_5867902 - - bonafide
# LA_0081 LA_T_5953323 - - bonafide
# LA_0081 LA_T_6007335 - - bonafide
# LA_0081 LA_T_6029472 - - bonafide
# LA_0081 LA_T_6049368 - - bonafide
# LA_0081 LA_T_6117487 - - bonafide
# LA_0081 LA_T_6227496 - - bonafide
# LA_0081 LA_T_6322780 - - bonafide
# LA_0081 LA_T_6370833 - - bonafide
# LA_0081 LA_T_6423802 - - bonafide
# LA_0081 LA_T_6426400 - - bonafide
# LA_0081 LA_T_6458679 - - bonafide
# LA_0081 LA_T_6541095 - - bonafide
# LA_0081 LA_T_6650735 - - bonafide
# LA_0081 LA_T_6669635 - - bonafide
# LA_0081 LA_T_6676313 - - bonafide
# LA_0081 LA_T_6769763 - - bonafide
# LA_0081 LA_T_6774634 - - bonafide
# LA_0081 LA_T_6808825 - - bonafide
# LA_0081 LA_T_7075102 - - bonafide
# LA_0081 LA_T_7145903 - - bonafide
# LA_0081 LA_T_7163377 - - bonafide
# LA_0081 LA_T_7183032 - - bonafide
# LA_0081 LA_T_7213473 - - bonafide
# LA_0081 LA_T_7292672 - - bonafide
# LA_0081 LA_T_7300523 - - bonafide
# LA_0081 LA_T_7337587 - - bonafide
# LA_0081 LA_T_7351960 - - bonafide
# LA_0081 LA_T_7363698 - - bonafide
# LA_0081 LA_T_7388260 - - bonafide
# LA_0081 LA_T_7419838 - - bonafide
# LA_0081 LA_T_7648440 - - bonafide
# LA_0081 LA_T_7697827 - - bonafide
# LA_0081 LA_T_7776350 - - bonafide
# LA_0081 LA_T_7848595 - - bonafide
# LA_0081 LA_T_7944618 - - bonafide
# LA_0081 LA_T_7967427 - - bonafide
# LA_0081 LA_T_7972168 - - bonafide
# LA_0081 LA_T_8025784 - - bonafide
# LA_0081 LA_T_8124095 - - bonafide
# LA_0081 LA_T_8140876 - - bonafide
# LA_0081 LA_T_8162147 - - bonafide
# LA_0081 LA_T_8173514 - - bonafide
# LA_0081 LA_T_8180259 - - bonafide
# LA_0081 LA_T_8200308 - - bonafide
# LA_0081 LA_T_8257553 - - bonafide
# LA_0081 LA_T_8326490 - - bonafide
# LA_0081 LA_T_8339895 - - bonafide
# LA_0081 LA_T_8344139 - - bonafide
# LA_0081 LA_T_8388870 - - bonafide
# LA_0081 LA_T_8438885 - - bonafide
# LA_0081 LA_T_8464594 - - bonafide
# LA_0081 LA_T_8511040 - - bonafide
# LA_0081 LA_T_8543938 - - bonafide
# LA_0081 LA_T_8615006 - - bonafide
# LA_0081 LA_T_8845558 - - bonafide
# LA_0081 LA_T_8852458 - - bonafide
# LA_0081 LA_T_8880498 - - bonafide
# LA_0081 LA_T_8893973 - - bonafide
# LA_0081 LA_T_8985520 - - bonafide
# LA_0081 LA_T_9017338 - - bonafide
# LA_0081 LA_T_9074196 - - bonafide
# LA_0081 LA_T_9213454 - - bonafide
# LA_0081 LA_T_9358107 - - bonafide
# LA_0081 LA_T_9396899 - - bonafide
# LA_0081 LA_T_9411327 - - bonafide
# LA_0081 LA_T_9504498 - - bonafide
# LA_0081 LA_T_9631300 - - bonafide
# LA_0081 LA_T_9650425 - - bonafide
# LA_0081 LA_T_9741234 - - bonafide
# LA_0081 LA_T_9746491 - - bonafide
# LA_0081 LA_T_9763074 - - bonafide
# LA_0081 LA_T_9838989 - - bonafide
# LA_0081 LA_T_9844620 - - bonafide
# LA_0081 LA_T_9896606 - - bonafide
# LA_0081 LA_T_9912890 - - bonafide
# LA_0082 LA_T_1199930 - - bonafide
# LA_0082 LA_T_1219386 - - bonafide
# LA_0082 LA_T_1487560 - - bonafide
# LA_0082 LA_T_1569908 - - bonafide
# LA_0082 LA_T_1584182 - - bonafide
# LA_0082 LA_T_1585521 - - bonafide
# LA_0082 LA_T_1623473 - - bonafide
# LA_0082 LA_T_1667973 - - bonafide
# LA_0082 LA_T_1756992 - - bonafide
# LA_0082 LA_T_1792767 - - bonafide
# LA_0082 LA_T_1830509 - - bonafide
# LA_0082 LA_T_1908512 - - bonafide
# LA_0082 LA_T_1923872 - - bonafide
# LA_0082 LA_T_1931571 - - bonafide
# LA_0082 LA_T_1934754 - - bonafide
# LA_0082 LA_T_2043279 - - bonafide
# LA_0082 LA_T_2130583 - - bonafide
# LA_0082 LA_T_2147641 - - bonafide
# LA_0082 LA_T_2216602 - - bonafide
# LA_0082 LA_T_2217523 - - bonafide
# LA_0082 LA_T_2520647 - - bonafide
# LA_0082 LA_T_2618051 - - bonafide
# LA_0082 LA_T_2675422 - - bonafide
# LA_0082 LA_T_2699884 - - bonafide
# LA_0082 LA_T_2925763 - - bonafide
# LA_0082 LA_T_3026804 - - bonafide
# LA_0082 LA_T_3068473 - - bonafide
# LA_0082 LA_T_3119779 - - bonafide
# LA_0082 LA_T_3171621 - - bonafide
# LA_0082 LA_T_3208992 - - bonafide
# LA_0082 LA_T_3226167 - - bonafide
# LA_0082 LA_T_3301728 - - bonafide
# LA_0082 LA_T_3324636 - - bonafide
# LA_0082 LA_T_3362906 - - bonafide
# LA_0082 LA_T_3513521 - - bonafide
# LA_0082 LA_T_3517928 - - bonafide
# LA_0082 LA_T_3524074 - - bonafide
# LA_0082 LA_T_3583591 - - bonafide
# LA_0082 LA_T_3611811 - - bonafide
# LA_0082 LA_T_3659915 - - bonafide
# LA_0082 LA_T_3661578 - - bonafide
# LA_0082 LA_T_3704574 - - bonafide
# LA_0082 LA_T_3748161 - - bonafide
# LA_0082 LA_T_3782527 - - bonafide
# LA_0082 LA_T_3915181 - - bonafide
# LA_0082 LA_T_3925776 - - bonafide
# LA_0082 LA_T_3963536 - - bonafide
# LA_0082 LA_T_4068159 - - bonafide
# LA_0082 LA_T_4169604 - - bonafide
# LA_0082 LA_T_4198628 - - bonafide
# LA_0082 LA_T_4210946 - - bonafide
# LA_0082 LA_T_4369129 - - bonafide
# LA_0082 LA_T_4451463 - - bonafide
# LA_0082 LA_T_4481879 - - bonafide
# LA_0082 LA_T_4486316 - - bonafide
# LA_0082 LA_T_4638884 - - bonafide
# LA_0082 LA_T_4710044 - - bonafide
# LA_0082 LA_T_4710920 - - bonafide
# LA_0082 LA_T_4740750 - - bonafide
# LA_0082 LA_T_4769298 - - bonafide
# LA_0082 LA_T_4772321 - - bonafide
# LA_0082 LA_T_4817040 - - bonafide
# LA_0082 LA_T_4860349 - - bonafide
# LA_0082 LA_T_4940666 - - bonafide
# LA_0082 LA_T_4991041 - - bonafide
# LA_0082 LA_T_5043225 - - bonafide
# LA_0082 LA_T_5103637 - - bonafide
# LA_0082 LA_T_5167256 - - bonafide
# LA_0082 LA_T_5353096 - - bonafide
# LA_0082 LA_T_5408992 - - bonafide
# LA_0082 LA_T_5443164 - - bonafide
# LA_0082 LA_T_5533183 - - bonafide
# LA_0082 LA_T_5599339 - - bonafide
# LA_0082 LA_T_5787857 - - bonafide
# LA_0082 LA_T_5890305 - - bonafide
# LA_0082 LA_T_6058119 - - bonafide
# LA_0082 LA_T_6078773 - - bonafide
# LA_0082 LA_T_6253524 - - bonafide
# LA_0082 LA_T_6368265 - - bonafide
# LA_0082 LA_T_6441166 - - bonafide
# LA_0082 LA_T_6496177 - - bonafide
# LA_0082 LA_T_6551574 - - bonafide
# LA_0082 LA_T_6554775 - - bonafide
# LA_0082 LA_T_6632006 - - bonafide
# LA_0082 LA_T_6666532 - - bonafide
# LA_0082 LA_T_6726155 - - bonafide
# LA_0082 LA_T_6766056 - - bonafide
# LA_0082 LA_T_6774071 - - bonafide
# LA_0082 LA_T_6795804 - - bonafide
# LA_0082 LA_T_6835345 - - bonafide
# LA_0082 LA_T_6946670 - - bonafide
# LA_0082 LA_T_7220833 - - bonafide
# LA_0082 LA_T_7278711 - - bonafide
# LA_0082 LA_T_7327413 - - bonafide
# LA_0082 LA_T_7367042 - - bonafide
# LA_0082 LA_T_7468662 - - bonafide
# LA_0082 LA_T_7667225 - - bonafide
# LA_0082 LA_T_7696598 - - bonafide
# LA_0082 LA_T_7815754 - - bonafide
# LA_0082 LA_T_7816568 - - bonafide
# LA_0082 LA_T_7851926 - - bonafide
# LA_0082 LA_T_8038233 - - bonafide
# LA_0082 LA_T_8040847 - - bonafide
# LA_0082 LA_T_8147741 - - bonafide
# LA_0082 LA_T_8193150 - - bonafide
# LA_0082 LA_T_8219979 - - bonafide
# LA_0082 LA_T_8230959 - - bonafide
# LA_0082 LA_T_8337767 - - bonafide
# LA_0082 LA_T_8374631 - - bonafide
# LA_0082 LA_T_8448396 - - bonafide
# LA_0082 LA_T_8522600 - - bonafide
# LA_0082 LA_T_8597023 - - bonafide
# LA_0082 LA_T_8597829 - - bonafide
# LA_0082 LA_T_8639914 - - bonafide
# LA_0082 LA_T_8705208 - - bonafide
# LA_0082 LA_T_8793633 - - bonafide
# LA_0082 LA_T_8806097 - - bonafide
# LA_0082 LA_T_8970804 - - bonafide
# LA_0082 LA_T_9075670 - - bonafide
# LA_0082 LA_T_9101277 - - bonafide
# LA_0082 LA_T_9390369 - - bonafide
# LA_0082 LA_T_9392229 - - bonafide
# LA_0082 LA_T_9408141 - - bonafide
# LA_0082 LA_T_9502120 - - bonafide
# LA_0082 LA_T_9634249 - - bonafide
# LA_0082 LA_T_9675042 - - bonafide
# LA_0082 LA_T_9728429 - - bonafide
# LA_0082 LA_T_9772981 - - bonafide
# LA_0082 LA_T_9778924 - - bonafide
# LA_0082 LA_T_9884197 - - bonafide
# LA_0082 LA_T_9955851 - - bonafide
# LA_0082 LA_T_9983805 - - bonafide
# LA_0083 LA_T_1031233 - - bonafide
# LA_0083 LA_T_1126222 - - bonafide
# LA_0083 LA_T_1188742 - - bonafide
# LA_0083 LA_T_1197695 - - bonafide
# LA_0083 LA_T_1261884 - - bonafide
# LA_0083 LA_T_1269847 - - bonafide
# LA_0083 LA_T_1504888 - - bonafide
# LA_0083 LA_T_1555189 - - bonafide
# LA_0083 LA_T_1662467 - - bonafide
# LA_0083 LA_T_1678844 - - bonafide
# LA_0083 LA_T_1745865 - - bonafide
# LA_0083 LA_T_1785278 - - bonafide
# LA_0083 LA_T_1793666 - - bonafide
# LA_0083 LA_T_1864383 - - bonafide
# LA_0083 LA_T_1873366 - - bonafide
# LA_0083 LA_T_1897788 - - bonafide
# LA_0083 LA_T_1914243 - - bonafide
# LA_0083 LA_T_1933449 - - bonafide
# LA_0083 LA_T_2193944 - - bonafide
# LA_0083 LA_T_2226656 - - bonafide
# LA_0083 LA_T_2304357 - - bonafide
# LA_0083 LA_T_2347217 - - bonafide
# LA_0083 LA_T_2376874 - - bonafide
# LA_0083 LA_T_2406356 - - bonafide
# LA_0083 LA_T_2419538 - - bonafide
# LA_0083 LA_T_2476165 - - bonafide
# LA_0083 LA_T_2535749 - - bonafide
# LA_0083 LA_T_2560383 - - bonafide
# LA_0083 LA_T_2709262 - - bonafide
# LA_0083 LA_T_2824772 - - bonafide
# LA_0083 LA_T_3022241 - - bonafide
# LA_0083 LA_T_3059635 - - bonafide
# LA_0083 LA_T_3060760 - - bonafide
# LA_0083 LA_T_3163425 - - bonafide
# LA_0083 LA_T_3325988 - - bonafide
# LA_0083 LA_T_3492130 - - bonafide
# LA_0083 LA_T_3508559 - - bonafide
# LA_0083 LA_T_3649480 - - bonafide
# LA_0083 LA_T_3729389 - - bonafide
# LA_0083 LA_T_3774973 - - bonafide
# LA_0083 LA_T_3812469 - - bonafide
# LA_0083 LA_T_3843638 - - bonafide
# LA_0083 LA_T_3865816 - - bonafide
# LA_0083 LA_T_3983390 - - bonafide
# LA_0083 LA_T_4027900 - - bonafide
# LA_0083 LA_T_4255653 - - bonafide
# LA_0083 LA_T_4302417 - - bonafide
# LA_0083 LA_T_4348949 - - bonafide
# LA_0083 LA_T_4396533 - - bonafide
# LA_0083 LA_T_4428088 - - bonafide
# LA_0083 LA_T_4486346 - - bonafide
# LA_0083 LA_T_4543133 - - bonafide
# LA_0083 LA_T_4591528 - - bonafide
# LA_0083 LA_T_4652434 - - bonafide
# LA_0083 LA_T_4667091 - - bonafide
# LA_0083 LA_T_4678612 - - bonafide
# LA_0083 LA_T_4734861 - - bonafide
# LA_0083 LA_T_4811800 - - bonafide
# LA_0083 LA_T_4855072 - - bonafide
# LA_0083 LA_T_4890539 - - bonafide
# LA_0083 LA_T_4927126 - - bonafide
# LA_0083 LA_T_4983711 - - bonafide
# LA_0083 LA_T_5294797 - - bonafide
# LA_0083 LA_T_5383824 - - bonafide
# LA_0083 LA_T_5481571 - - bonafide
# LA_0083 LA_T_5675574 - - bonafide
# LA_0083 LA_T_5759484 - - bonafide
# LA_0083 LA_T_5786461 - - bonafide
# LA_0083 LA_T_5900964 - - bonafide
# LA_0083 LA_T_5918833 - - bonafide
# LA_0083 LA_T_5949193 - - bonafide
# LA_0083 LA_T_5973899 - - bonafide
# LA_0083 LA_T_6150466 - - bonafide
# LA_0083 LA_T_6212732 - - bonafide
# LA_0083 LA_T_6362766 - - bonafide
# LA_0083 LA_T_6371068 - - bonafide
# LA_0083 LA_T_6457872 - - bonafide
# LA_0083 LA_T_6521388 - - bonafide
# LA_0083 LA_T_6531051 - - bonafide
# LA_0083 LA_T_6540438 - - bonafide
# LA_0083 LA_T_6620806 - - bonafide
# LA_0083 LA_T_6668176 - - bonafide
# LA_0083 LA_T_6763611 - - bonafide
# LA_0083 LA_T_6799312 - - bonafide
# LA_0083 LA_T_6813958 - - bonafide
# LA_0083 LA_T_6949400 - - bonafide
# LA_0083 LA_T_6995687 - - bonafide
# LA_0083 LA_T_7000444 - - bonafide
# LA_0083 LA_T_7024437 - - bonafide
# LA_0083 LA_T_7024613 - - bonafide
# LA_0083 LA_T_7234808 - - bonafide
# LA_0083 LA_T_7254652 - - bonafide
# LA_0083 LA_T_7344886 - - bonafide
# LA_0083 LA_T_7504201 - - bonafide
# LA_0083 LA_T_7515281 - - bonafide
# LA_0083 LA_T_7566470 - - bonafide
# LA_0083 LA_T_7613910 - - bonafide
# LA_0083 LA_T_7746591 - - bonafide
# LA_0083 LA_T_7855509 - - bonafide
# LA_0083 LA_T_7861379 - - bonafide
# LA_0083 LA_T_7866363 - - bonafide
# LA_0083 LA_T_7944475 - - bonafide
# LA_0083 LA_T_7974354 - - bonafide
# LA_0083 LA_T_7974410 - - bonafide
# LA_0083 LA_T_7974459 - - bonafide
# LA_0083 LA_T_8032109 - - bonafide
# LA_0083 LA_T_8049822 - - bonafide
# LA_0083 LA_T_8156237 - - bonafide
# LA_0083 LA_T_8214917 - - bonafide
# LA_0083 LA_T_8387777 - - bonafide
# LA_0083 LA_T_8423394 - - bonafide
# LA_0083 LA_T_8503822 - - bonafide
# LA_0083 LA_T_8520270 - - bonafide
# LA_0083 LA_T_8760338 - - bonafide
# LA_0083 LA_T_8791339 - - bonafide
# LA_0083 LA_T_8865587 - - bonafide
# LA_0083 LA_T_8918938 - - bonafide
# LA_0083 LA_T_8987811 - - bonafide
# LA_0083 LA_T_8989127 - - bonafide
# LA_0083 LA_T_9189420 - - bonafide
# LA_0083 LA_T_9203438 - - bonafide
# LA_0083 LA_T_9226313 - - bonafide
# LA_0083 LA_T_9275052 - - bonafide
# LA_0083 LA_T_9320200 - - bonafide
# LA_0083 LA_T_9402563 - - bonafide
# LA_0083 LA_T_9519970 - - bonafide
# LA_0083 LA_T_9565794 - - bonafide
# LA_0083 LA_T_9644594 - - bonafide
# LA_0083 LA_T_9660280 - - bonafide
# LA_0083 LA_T_9673436 - - bonafide
# LA_0083 LA_T_9717737 - - bonafide
# LA_0083 LA_T_9923341 - - bonafide
# LA_0084 LA_T_1011221 - - bonafide
# LA_0084 LA_T_1158098 - - bonafide
# LA_0084 LA_T_1483721 - - bonafide
# LA_0084 LA_T_1590181 - - bonafide
# LA_0084 LA_T_1622807 - - bonafide
# LA_0084 LA_T_1831818 - - bonafide
# LA_0084 LA_T_1878391 - - bonafide
# LA_0084 LA_T_1895676 - - bonafide
# LA_0084 LA_T_1948575 - - bonafide
# LA_0084 LA_T_1963829 - - bonafide
# LA_0084 LA_T_1970201 - - bonafide
# LA_0084 LA_T_2109303 - - bonafide
# LA_0084 LA_T_2280500 - - bonafide
# LA_0084 LA_T_2450169 - - bonafide
# LA_0084 LA_T_2454697 - - bonafide
# LA_0084 LA_T_2474244 - - bonafide
# LA_0084 LA_T_2547007 - - bonafide
# LA_0084 LA_T_2579152 - - bonafide
# LA_0084 LA_T_2822179 - - bonafide
# LA_0084 LA_T_2852133 - - bonafide
# LA_0084 LA_T_3041149 - - bonafide
# LA_0084 LA_T_3041626 - - bonafide
# LA_0084 LA_T_3058432 - - bonafide
# LA_0084 LA_T_3154528 - - bonafide
# LA_0084 LA_T_3204710 - - bonafide
# LA_0084 LA_T_3325414 - - bonafide
# LA_0084 LA_T_3354987 - - bonafide
# LA_0084 LA_T_3397728 - - bonafide
# LA_0084 LA_T_3426509 - - bonafide
# LA_0084 LA_T_3452222 - - bonafide
# LA_0084 LA_T_3624315 - - bonafide
# LA_0084 LA_T_3641295 - - bonafide
# LA_0084 LA_T_3643851 - - bonafide
# LA_0084 LA_T_3679258 - - bonafide
# LA_0084 LA_T_3725307 - - bonafide
# LA_0084 LA_T_3956959 - - bonafide
# LA_0084 LA_T_3968554 - - bonafide
# LA_0084 LA_T_4072277 - - bonafide
# LA_0084 LA_T_4075500 - - bonafide
# LA_0084 LA_T_4124955 - - bonafide
# LA_0084 LA_T_4337007 - - bonafide
# LA_0084 LA_T_4345283 - - bonafide
# LA_0084 LA_T_4350897 - - bonafide
# LA_0084 LA_T_4366892 - - bonafide
# LA_0084 LA_T_4460814 - - bonafide
# LA_0084 LA_T_4494495 - - bonafide
# LA_0084 LA_T_4565832 - - bonafide
# LA_0084 LA_T_4575102 - - bonafide
# LA_0084 LA_T_4606578 - - bonafide
# LA_0084 LA_T_4679163 - - bonafide
# LA_0084 LA_T_4778437 - - bonafide
# LA_0084 LA_T_4801937 - - bonafide
# LA_0084 LA_T_4807785 - - bonafide
# LA_0084 LA_T_4825064 - - bonafide
# LA_0084 LA_T_4829102 - - bonafide
# LA_0084 LA_T_4848180 - - bonafide
# LA_0084 LA_T_4853464 - - bonafide
# LA_0084 LA_T_5051764 - - bonafide
# LA_0084 LA_T_5140325 - - bonafide
# LA_0084 LA_T_5179598 - - bonafide
# LA_0084 LA_T_5214235 - - bonafide
# LA_0084 LA_T_5235221 - - bonafide
# LA_0084 LA_T_5387155 - - bonafide
# LA_0084 LA_T_5525305 - - bonafide
# LA_0084 LA_T_5535201 - - bonafide
# LA_0084 LA_T_5633732 - - bonafide
# LA_0084 LA_T_5637214 - - bonafide
# LA_0084 LA_T_5751244 - - bonafide
# LA_0084 LA_T_5795459 - - bonafide
# LA_0084 LA_T_5796504 - - bonafide
# LA_0084 LA_T_5824253 - - bonafide
# LA_0084 LA_T_5855384 - - bonafide
# LA_0084 LA_T_6106283 - - bonafide
# LA_0084 LA_T_6139557 - - bonafide
# LA_0084 LA_T_6237013 - - bonafide
# LA_0084 LA_T_6524013 - - bonafide
# LA_0084 LA_T_6602884 - - bonafide
# LA_0084 LA_T_6698424 - - bonafide
# LA_0084 LA_T_6710807 - - bonafide
# LA_0084 LA_T_6812855 - - bonafide
# LA_0084 LA_T_6978009 - - bonafide
# LA_0084 LA_T_6982603 - - bonafide
# LA_0084 LA_T_7051313 - - bonafide
# LA_0084 LA_T_7086580 - - bonafide
# LA_0084 LA_T_7165182 - - bonafide
# LA_0084 LA_T_7226623 - - bonafide
# LA_0084 LA_T_7231745 - - bonafide
# LA_0084 LA_T_7317221 - - bonafide
# LA_0084 LA_T_7359075 - - bonafide
# LA_0084 LA_T_7445288 - - bonafide
# LA_0084 LA_T_7533042 - - bonafide
# LA_0084 LA_T_7583143 - - bonafide
# LA_0084 LA_T_7690633 - - bonafide
# LA_0084 LA_T_7717952 - - bonafide
# LA_0084 LA_T_7746928 - - bonafide
# LA_0084 LA_T_7778575 - - bonafide
# LA_0084 LA_T_7786868 - - bonafide
# LA_0084 LA_T_7839314 - - bonafide
# LA_0084 LA_T_7878810 - - bonafide
# LA_0084 LA_T_7962007 - - bonafide
# LA_0084 LA_T_8007489 - - bonafide
# LA_0084 LA_T_8052308 - - bonafide
# LA_0084 LA_T_8057044 - - bonafide
# LA_0084 LA_T_8105555 - - bonafide
# LA_0084 LA_T_8164024 - - bonafide
# LA_0084 LA_T_8185303 - - bonafide
# LA_0084 LA_T_8196808 - - bonafide
# LA_0084 LA_T_8290600 - - bonafide
# LA_0084 LA_T_8342717 - - bonafide
# LA_0084 LA_T_8405652 - - bonafide
# LA_0084 LA_T_8571358 - - bonafide
# LA_0084 LA_T_8589988 - - bonafide
# LA_0084 LA_T_8780063 - - bonafide
# LA_0084 LA_T_8781605 - - bonafide
# LA_0084 LA_T_8807017 - - bonafide
# LA_0084 LA_T_8812445 - - bonafide
# LA_0084 LA_T_8919107 - - bonafide
# LA_0084 LA_T_8983353 - - bonafide
# LA_0084 LA_T_9002298 - - bonafide
# LA_0084 LA_T_9265598 - - bonafide
# LA_0084 LA_T_9529079 - - bonafide
# LA_0084 LA_T_9529868 - - bonafide
# LA_0084 LA_T_9593260 - - bonafide
# LA_0084 LA_T_9603308 - - bonafide
# LA_0084 LA_T_9749112 - - bonafide
# LA_0084 LA_T_9784585 - - bonafide
# LA_0084 LA_T_9881753 - - bonafide
# LA_0085 LA_T_1023546 - - bonafide
# LA_0085 LA_T_1034923 - - bonafide
# LA_0085 LA_T_1114980 - - bonafide
# LA_0085 LA_T_1209325 - - bonafide
# LA_0085 LA_T_1302087 - - bonafide
# LA_0085 LA_T_1338417 - - bonafide
# LA_0085 LA_T_1385311 - - bonafide
# LA_0085 LA_T_1495245 - - bonafide
# LA_0085 LA_T_1563365 - - bonafide
# LA_0085 LA_T_1581753 - - bonafide
# LA_0085 LA_T_1646363 - - bonafide
# LA_0085 LA_T_1691318 - - bonafide
# LA_0085 LA_T_1698724 - - bonafide
# LA_0085 LA_T_1717556 - - bonafide
# LA_0085 LA_T_1922746 - - bonafide
# LA_0085 LA_T_2167549 - - bonafide
# LA_0085 LA_T_2361518 - - bonafide
# LA_0085 LA_T_2366817 - - bonafide
# LA_0085 LA_T_2435826 - - bonafide
# LA_0085 LA_T_2441274 - - bonafide
# LA_0085 LA_T_2653144 - - bonafide
# LA_0085 LA_T_2801814 - - bonafide
# LA_0085 LA_T_2829414 - - bonafide
# LA_0085 LA_T_3064822 - - bonafide
# LA_0085 LA_T_3127267 - - bonafide
# LA_0085 LA_T_3167085 - - bonafide
# LA_0085 LA_T_3197627 - - bonafide
# LA_0085 LA_T_3222760 - - bonafide
# LA_0085 LA_T_3224558 - - bonafide
# LA_0085 LA_T_3228713 - - bonafide
# LA_0085 LA_T_3365001 - - bonafide
# LA_0085 LA_T_3416785 - - bonafide
# LA_0085 LA_T_3446393 - - bonafide
# LA_0085 LA_T_3525725 - - bonafide
# LA_0085 LA_T_3607190 - - bonafide
# LA_0085 LA_T_3686008 - - bonafide
# LA_0085 LA_T_3831604 - - bonafide
# LA_0085 LA_T_3891170 - - bonafide
# LA_0085 LA_T_3963452 - - bonafide
# LA_0085 LA_T_3978678 - - bonafide
# LA_0085 LA_T_4043474 - - bonafide
# LA_0085 LA_T_4100536 - - bonafide
# LA_0085 LA_T_4123333 - - bonafide
# LA_0085 LA_T_4257400 - - bonafide
# LA_0085 LA_T_4406929 - - bonafide
# LA_0085 LA_T_4485359 - - bonafide
# LA_0085 LA_T_4578519 - - bonafide
# LA_0085 LA_T_4615562 - - bonafide
# LA_0085 LA_T_4682842 - - bonafide
# LA_0085 LA_T_4711197 - - bonafide
# LA_0085 LA_T_4839122 - - bonafide
# LA_0085 LA_T_4925419 - - bonafide
# LA_0085 LA_T_4926626 - - bonafide
# LA_0085 LA_T_5024980 - - bonafide
# LA_0085 LA_T_5127288 - - bonafide
# LA_0085 LA_T_5127485 - - bonafide
# LA_0085 LA_T_5239258 - - bonafide
# LA_0085 LA_T_5304944 - - bonafide
# LA_0085 LA_T_5576506 - - bonafide
# LA_0085 LA_T_5616380 - - bonafide
# LA_0085 LA_T_5806387 - - bonafide
# LA_0085 LA_T_5837486 - - bonafide
# LA_0085 LA_T_5891808 - - bonafide
# LA_0085 LA_T_5968030 - - bonafide
# LA_0085 LA_T_5991300 - - bonafide
# LA_0085 LA_T_6100680 - - bonafide
# LA_0085 LA_T_6164845 - - bonafide
# LA_0085 LA_T_6221058 - - bonafide
# LA_0085 LA_T_6268937 - - bonafide
# LA_0085 LA_T_6290647 - - bonafide
# LA_0085 LA_T_6350377 - - bonafide
# LA_0085 LA_T_6407273 - - bonafide
# LA_0085 LA_T_6416841 - - bonafide
# LA_0085 LA_T_6499936 - - bonafide
# LA_0085 LA_T_6591503 - - bonafide
# LA_0085 LA_T_6638771 - - bonafide
# LA_0085 LA_T_6654102 - - bonafide
# LA_0085 LA_T_6789290 - - bonafide
# LA_0085 LA_T_6858608 - - bonafide
# LA_0085 LA_T_6859654 - - bonafide
# LA_0085 LA_T_6902662 - - bonafide
# LA_0085 LA_T_6954528 - - bonafide
# LA_0085 LA_T_6994918 - - bonafide
# LA_0085 LA_T_7006038 - - bonafide
# LA_0085 LA_T_7024695 - - bonafide
# LA_0085 LA_T_7144134 - - bonafide
# LA_0085 LA_T_7153704 - - bonafide
# LA_0085 LA_T_7374710 - - bonafide
# LA_0085 LA_T_7477418 - - bonafide
# LA_0085 LA_T_7478780 - - bonafide
# LA_0085 LA_T_7549713 - - bonafide
# LA_0085 LA_T_7566003 - - bonafide
# LA_0085 LA_T_7607573 - - bonafide
# LA_0085 LA_T_7645518 - - bonafide
# LA_0085 LA_T_7674329 - - bonafide
# LA_0085 LA_T_7826829 - - bonafide
# LA_0085 LA_T_7843393 - - bonafide
# LA_0085 LA_T_7965624 - - bonafide
# LA_0085 LA_T_7990660 - - bonafide
# LA_0085 LA_T_8042177 - - bonafide
# LA_0085 LA_T_8096613 - - bonafide
# LA_0085 LA_T_8178089 - - bonafide
# LA_0085 LA_T_8209686 - - bonafide
# LA_0085 LA_T_8371319 - - bonafide
# LA_0085 LA_T_8415843 - - bonafide
# LA_0085 LA_T_8459920 - - bonafide
# LA_0085 LA_T_8593946 - - bonafide
# LA_0085 LA_T_8665775 - - bonafide
# LA_0085 LA_T_8690927 - - bonafide
# LA_0085 LA_T_8763090 - - bonafide
# LA_0085 LA_T_8814910 - - bonafide
# LA_0085 LA_T_8819900 - - bonafide
# LA_0085 LA_T_8853344 - - bonafide
# LA_0085 LA_T_8974364 - - bonafide
# LA_0085 LA_T_9010570 - - bonafide
# LA_0085 LA_T_9022965 - - bonafide
# LA_0085 LA_T_9032022 - - bonafide
# LA_0085 LA_T_9043274 - - bonafide
# LA_0085 LA_T_9190599 - - bonafide
# LA_0085 LA_T_9192060 - - bonafide
# LA_0085 LA_T_9444221 - - bonafide
# LA_0085 LA_T_9480695 - - bonafide
# LA_0085 LA_T_9539101 - - bonafide
# LA_0085 LA_T_9644311 - - bonafide
# LA_0085 LA_T_9713701 - - bonafide
# LA_0085 LA_T_9944200 - - bonafide
# LA_0085 LA_T_9976341 - - bonafide
# LA_0086 LA_T_1013597 - - bonafide
# LA_0086 LA_T_1186717 - - bonafide
# LA_0086 LA_T_1302542 - - bonafide
# LA_0086 LA_T_1477639 - - bonafide
# LA_0086 LA_T_1495856 - - bonafide
# LA_0086 LA_T_1501005 - - bonafide
# LA_0086 LA_T_1536675 - - bonafide
# LA_0086 LA_T_1569381 - - bonafide
# LA_0086 LA_T_1611587 - - bonafide
# LA_0086 LA_T_1639691 - - bonafide
# LA_0086 LA_T_1731260 - - bonafide
# LA_0086 LA_T_1836557 - - bonafide
# LA_0086 LA_T_1861398 - - bonafide
# LA_0086 LA_T_1979527 - - bonafide
# LA_0086 LA_T_2026553 - - bonafide
# LA_0086 LA_T_2084171 - - bonafide
# LA_0086 LA_T_2109491 - - bonafide
# LA_0086 LA_T_2113561 - - bonafide
# LA_0086 LA_T_2139401 - - bonafide
# LA_0086 LA_T_2267510 - - bonafide
# LA_0086 LA_T_2498754 - - bonafide
# LA_0086 LA_T_2547751 - - bonafide
# LA_0086 LA_T_2572311 - - bonafide
# LA_0086 LA_T_2815613 - - bonafide
# LA_0086 LA_T_2959505 - - bonafide
# LA_0086 LA_T_2996311 - - bonafide
# LA_0086 LA_T_3050170 - - bonafide
# LA_0086 LA_T_3100997 - - bonafide
# LA_0086 LA_T_3123920 - - bonafide
# LA_0086 LA_T_3228820 - - bonafide
# LA_0086 LA_T_3264459 - - bonafide
# LA_0086 LA_T_3264613 - - bonafide
# LA_0086 LA_T_3388956 - - bonafide
# LA_0086 LA_T_3419879 - - bonafide
# LA_0086 LA_T_3643681 - - bonafide
# LA_0086 LA_T_3744808 - - bonafide
# LA_0086 LA_T_3784759 - - bonafide
# LA_0086 LA_T_4113721 - - bonafide
# LA_0086 LA_T_4160149 - - bonafide
# LA_0086 LA_T_4204424 - - bonafide
# LA_0086 LA_T_4293504 - - bonafide
# LA_0086 LA_T_4298489 - - bonafide
# LA_0086 LA_T_4334140 - - bonafide
# LA_0086 LA_T_4350005 - - bonafide
# LA_0086 LA_T_4350540 - - bonafide
# LA_0086 LA_T_4365113 - - bonafide
# LA_0086 LA_T_4456925 - - bonafide
# LA_0086 LA_T_4546797 - - bonafide
# LA_0086 LA_T_4565780 - - bonafide
# LA_0086 LA_T_4566714 - - bonafide
# LA_0086 LA_T_4614402 - - bonafide
# LA_0086 LA_T_4651598 - - bonafide
# LA_0086 LA_T_4664739 - - bonafide
# LA_0086 LA_T_4666356 - - bonafide
# LA_0086 LA_T_4740742 - - bonafide
# LA_0086 LA_T_4877664 - - bonafide
# LA_0086 LA_T_4966921 - - bonafide
# LA_0086 LA_T_4968559 - - bonafide
# LA_0086 LA_T_5132134 - - bonafide
# LA_0086 LA_T_5170336 - - bonafide
# LA_0086 LA_T_5187822 - - bonafide
# LA_0086 LA_T_5278239 - - bonafide
# LA_0086 LA_T_5362691 - - bonafide
# LA_0086 LA_T_5462809 - - bonafide
# LA_0086 LA_T_5520907 - - bonafide
# LA_0086 LA_T_5544402 - - bonafide
# LA_0086 LA_T_5611078 - - bonafide
# LA_0086 LA_T_5656982 - - bonafide
# LA_0086 LA_T_5680519 - - bonafide
# LA_0086 LA_T_5715699 - - bonafide
# LA_0086 LA_T_5724427 - - bonafide
# LA_0086 LA_T_5788985 - - bonafide
# LA_0086 LA_T_5831523 - - bonafide
# LA_0086 LA_T_6013298 - - bonafide
# LA_0086 LA_T_6034182 - - bonafide
# LA_0086 LA_T_6073936 - - bonafide
# LA_0086 LA_T_6150186 - - bonafide
# LA_0086 LA_T_6216316 - - bonafide
# LA_0086 LA_T_6217520 - - bonafide
# LA_0086 LA_T_6222543 - - bonafide
# LA_0086 LA_T_6292792 - - bonafide
# LA_0086 LA_T_6302089 - - bonafide
# LA_0086 LA_T_6390530 - - bonafide
# LA_0086 LA_T_6401833 - - bonafide
# LA_0086 LA_T_6435392 - - bonafide
# LA_0086 LA_T_6476075 - - bonafide
# LA_0086 LA_T_6684256 - - bonafide
# LA_0086 LA_T_6704810 - - bonafide
# LA_0086 LA_T_6741908 - - bonafide
# LA_0086 LA_T_6780253 - - bonafide
# LA_0086 LA_T_6784918 - - bonafide
# LA_0086 LA_T_6807168 - - bonafide
# LA_0086 LA_T_6992885 - - bonafide
# LA_0086 LA_T_7133372 - - bonafide
# LA_0086 LA_T_7179410 - - bonafide
# LA_0086 LA_T_7197738 - - bonafide
# LA_0086 LA_T_7260727 - - bonafide
# LA_0086 LA_T_7279842 - - bonafide
# LA_0086 LA_T_7301103 - - bonafide
# LA_0086 LA_T_7422011 - - bonafide
# LA_0086 LA_T_7422329 - - bonafide
# LA_0086 LA_T_7590799 - - bonafide
# LA_0086 LA_T_7659619 - - bonafide
# LA_0086 LA_T_7700407 - - bonafide
# LA_0086 LA_T_7702835 - - bonafide
# LA_0086 LA_T_7779179 - - bonafide
# LA_0086 LA_T_7988057 - - bonafide
# LA_0086 LA_T_8093170 - - bonafide
# LA_0086 LA_T_8119863 - - bonafide
# LA_0086 LA_T_8285892 - - bonafide
# LA_0086 LA_T_8303411 - - bonafide
# LA_0086 LA_T_8417406 - - bonafide
# LA_0086 LA_T_8521460 - - bonafide
# LA_0086 LA_T_8657239 - - bonafide
# LA_0086 LA_T_8854115 - - bonafide
# LA_0086 LA_T_8864733 - - bonafide
# LA_0086 LA_T_9026573 - - bonafide
# LA_0086 LA_T_9029058 - - bonafide
# LA_0086 LA_T_9079590 - - bonafide
# LA_0086 LA_T_9166813 - - bonafide
# LA_0086 LA_T_9208716 - - bonafide
# LA_0086 LA_T_9378495 - - bonafide
# LA_0086 LA_T_9447463 - - bonafide
# LA_0086 LA_T_9508827 - - bonafide
# LA_0086 LA_T_9513704 - - bonafide
# LA_0086 LA_T_9630620 - - bonafide
# LA_0086 LA_T_9773629 - - bonafide
# LA_0087 LA_T_1045294 - - bonafide
# LA_0087 LA_T_1130924 - - bonafide
# LA_0087 LA_T_1160090 - - bonafide
# LA_0087 LA_T_1238061 - - bonafide
# LA_0087 LA_T_1248092 - - bonafide
# LA_0087 LA_T_1316001 - - bonafide
# LA_0087 LA_T_1321385 - - bonafide
# LA_0087 LA_T_1394641 - - bonafide
# LA_0087 LA_T_1410416 - - bonafide
# LA_0087 LA_T_1423202 - - bonafide
# LA_0087 LA_T_1482834 - - bonafide
# LA_0087 LA_T_1518499 - - bonafide
# LA_0087 LA_T_1599278 - - bonafide
# LA_0087 LA_T_1799958 - - bonafide
# LA_0087 LA_T_1940419 - - bonafide
# LA_0087 LA_T_2034214 - - bonafide
# LA_0087 LA_T_2129069 - - bonafide
# LA_0087 LA_T_2202252 - - bonafide
# LA_0087 LA_T_2465871 - - bonafide
# LA_0087 LA_T_2579587 - - bonafide
# LA_0087 LA_T_2579773 - - bonafide
# LA_0087 LA_T_2684786 - - bonafide
# LA_0087 LA_T_2716529 - - bonafide
# LA_0087 LA_T_2902854 - - bonafide
# LA_0087 LA_T_2936703 - - bonafide
# LA_0087 LA_T_3046012 - - bonafide
# LA_0087 LA_T_3070659 - - bonafide
# LA_0087 LA_T_3220828 - - bonafide
# LA_0087 LA_T_3230541 - - bonafide
# LA_0087 LA_T_3324661 - - bonafide
# LA_0087 LA_T_3383878 - - bonafide
# LA_0087 LA_T_3499323 - - bonafide
# LA_0087 LA_T_3538502 - - bonafide
# LA_0087 LA_T_3582106 - - bonafide
# LA_0087 LA_T_3647140 - - bonafide
# LA_0087 LA_T_3683196 - - bonafide
# LA_0087 LA_T_3697922 - - bonafide
# LA_0087 LA_T_3938480 - - bonafide
# LA_0087 LA_T_4006888 - - bonafide
# LA_0087 LA_T_4036336 - - bonafide
# LA_0087 LA_T_4196090 - - bonafide
# LA_0087 LA_T_4211750 - - bonafide
# LA_0087 LA_T_4253209 - - bonafide
# LA_0087 LA_T_4408412 - - bonafide
# LA_0087 LA_T_4458942 - - bonafide
# LA_0087 LA_T_4621617 - - bonafide
# LA_0087 LA_T_4694969 - - bonafide
# LA_0087 LA_T_4720967 - - bonafide
# LA_0087 LA_T_4860972 - - bonafide
# LA_0087 LA_T_4898635 - - bonafide
# LA_0087 LA_T_4972864 - - bonafide
# LA_0087 LA_T_5037374 - - bonafide
# LA_0087 LA_T_5049541 - - bonafide
# LA_0087 LA_T_5417767 - - bonafide
# LA_0087 LA_T_5619335 - - bonafide
# LA_0087 LA_T_5644159 - - bonafide
# LA_0087 LA_T_5719913 - - bonafide
# LA_0087 LA_T_5795707 - - bonafide
# LA_0087 LA_T_5865772 - - bonafide
# LA_0087 LA_T_5872172 - - bonafide
# LA_0087 LA_T_5934685 - - bonafide
# LA_0087 LA_T_6015645 - - bonafide
# LA_0087 LA_T_6069460 - - bonafide
# LA_0087 LA_T_6087132 - - bonafide
# LA_0087 LA_T_6119283 - - bonafide
# LA_0087 LA_T_6197882 - - bonafide
# LA_0087 LA_T_6345056 - - bonafide
# LA_0087 LA_T_6369221 - - bonafide
# LA_0087 LA_T_6413988 - - bonafide
# LA_0087 LA_T_6435787 - - bonafide
# LA_0087 LA_T_6475724 - - bonafide
# LA_0087 LA_T_6487011 - - bonafide
# LA_0087 LA_T_6627269 - - bonafide
# LA_0087 LA_T_6669331 - - bonafide
# LA_0087 LA_T_6686104 - - bonafide
# LA_0087 LA_T_6708956 - - bonafide
# LA_0087 LA_T_6742582 - - bonafide
# LA_0087 LA_T_6756969 - - bonafide
# LA_0087 LA_T_6776173 - - bonafide
# LA_0087 LA_T_6861216 - - bonafide
# LA_0087 LA_T_6958535 - - bonafide
# LA_0087 LA_T_6962044 - - bonafide
# LA_0087 LA_T_6993201 - - bonafide
# LA_0087 LA_T_7052804 - - bonafide
# LA_0087 LA_T_7108923 - - bonafide
# LA_0087 LA_T_7275897 - - bonafide
# LA_0087 LA_T_7288960 - - bonafide
# LA_0087 LA_T_7310231 - - bonafide
# LA_0087 LA_T_7357748 - - bonafide
# LA_0087 LA_T_7457149 - - bonafide
# LA_0087 LA_T_7514330 - - bonafide
# LA_0087 LA_T_7601537 - - bonafide
# LA_0087 LA_T_7661468 - - bonafide
# LA_0087 LA_T_7676958 - - bonafide
# LA_0087 LA_T_7708952 - - bonafide
# LA_0087 LA_T_7740663 - - bonafide
# LA_0087 LA_T_7750406 - - bonafide
# LA_0087 LA_T_7755046 - - bonafide
# LA_0087 LA_T_7774011 - - bonafide
# LA_0087 LA_T_7871766 - - bonafide
# LA_0087 LA_T_7934464 - - bonafide
# LA_0087 LA_T_8220892 - - bonafide
# LA_0087 LA_T_8272787 - - bonafide
# LA_0087 LA_T_8283217 - - bonafide
# LA_0087 LA_T_8459875 - - bonafide
# LA_0087 LA_T_8473215 - - bonafide
# LA_0087 LA_T_8562513 - - bonafide
# LA_0087 LA_T_8651978 - - bonafide
# LA_0087 LA_T_8874328 - - bonafide
# LA_0087 LA_T_8898922 - - bonafide
# LA_0087 LA_T_8971944 - - bonafide
# LA_0087 LA_T_9113475 - - bonafide
# LA_0087 LA_T_9133356 - - bonafide
# LA_0087 LA_T_9161988 - - bonafide
# LA_0087 LA_T_9181464 - - bonafide
# LA_0087 LA_T_9243374 - - bonafide
# LA_0087 LA_T_9276305 - - bonafide
# LA_0087 LA_T_9384908 - - bonafide
# LA_0087 LA_T_9433144 - - bonafide
# LA_0087 LA_T_9476394 - - bonafide
# LA_0087 LA_T_9526706 - - bonafide
# LA_0087 LA_T_9544820 - - bonafide
# LA_0087 LA_T_9748392 - - bonafide
# LA_0087 LA_T_9779411 - - bonafide
# LA_0087 LA_T_9803057 - - bonafide
# LA_0087 LA_T_9863654 - - bonafide
# LA_0087 LA_T_9882639 - - bonafide
# LA_0088 LA_T_1007571 - - bonafide
# LA_0088 LA_T_1052790 - - bonafide
# LA_0088 LA_T_1075018 - - bonafide
# LA_0088 LA_T_1193043 - - bonafide
# LA_0088 LA_T_1241016 - - bonafide
# LA_0088 LA_T_1269462 - - bonafide
# LA_0088 LA_T_1307755 - - bonafide
# LA_0088 LA_T_1498247 - - bonafide
# LA_0088 LA_T_1535496 - - bonafide
# LA_0088 LA_T_1544986 - - bonafide
# LA_0088 LA_T_1646676 - - bonafide
# LA_0088 LA_T_1725860 - - bonafide
# LA_0088 LA_T_1740931 - - bonafide
# LA_0088 LA_T_1745993 - - bonafide
# LA_0088 LA_T_1770624 - - bonafide
# LA_0088 LA_T_1856855 - - bonafide
# LA_0088 LA_T_1859956 - - bonafide
# LA_0088 LA_T_2032733 - - bonafide
# LA_0088 LA_T_2033687 - - bonafide
# LA_0088 LA_T_2101210 - - bonafide
# LA_0088 LA_T_2118892 - - bonafide
# LA_0088 LA_T_2127844 - - bonafide
# LA_0088 LA_T_2189446 - - bonafide
# LA_0088 LA_T_2207566 - - bonafide
# LA_0088 LA_T_2245366 - - bonafide
# LA_0088 LA_T_2257126 - - bonafide
# LA_0088 LA_T_2371044 - - bonafide
# LA_0088 LA_T_2397067 - - bonafide
# LA_0088 LA_T_2559146 - - bonafide
# LA_0088 LA_T_2560396 - - bonafide
# LA_0088 LA_T_2580639 - - bonafide
# LA_0088 LA_T_2646474 - - bonafide
# LA_0088 LA_T_2707835 - - bonafide
# LA_0088 LA_T_2720285 - - bonafide
# LA_0088 LA_T_2726428 - - bonafide
# LA_0088 LA_T_2823943 - - bonafide
# LA_0088 LA_T_3233814 - - bonafide
# LA_0088 LA_T_3268169 - - bonafide
# LA_0088 LA_T_3422948 - - bonafide
# LA_0088 LA_T_3447323 - - bonafide
# LA_0088 LA_T_3449995 - - bonafide
# LA_0088 LA_T_3580523 - - bonafide
# LA_0088 LA_T_3610653 - - bonafide
# LA_0088 LA_T_3747046 - - bonafide
# LA_0088 LA_T_3769045 - - bonafide
# LA_0088 LA_T_3800372 - - bonafide
# LA_0088 LA_T_4128527 - - bonafide
# LA_0088 LA_T_4140135 - - bonafide
# LA_0088 LA_T_4246466 - - bonafide
# LA_0088 LA_T_4704925 - - bonafide
# LA_0088 LA_T_4819902 - - bonafide
# LA_0088 LA_T_4900136 - - bonafide
# LA_0088 LA_T_4961493 - - bonafide
# LA_0088 LA_T_5061172 - - bonafide
# LA_0088 LA_T_5118997 - - bonafide
# LA_0088 LA_T_5154755 - - bonafide
# LA_0088 LA_T_5193056 - - bonafide
# LA_0088 LA_T_5302452 - - bonafide
# LA_0088 LA_T_5314492 - - bonafide
# LA_0088 LA_T_5428638 - - bonafide
# LA_0088 LA_T_5441846 - - bonafide
# LA_0088 LA_T_5463262 - - bonafide
# LA_0088 LA_T_5649093 - - bonafide
# LA_0088 LA_T_5683238 - - bonafide
# LA_0088 LA_T_5733848 - - bonafide
# LA_0088 LA_T_5834325 - - bonafide
# LA_0088 LA_T_5896323 - - bonafide
# LA_0088 LA_T_5971038 - - bonafide
# LA_0088 LA_T_5978032 - - bonafide
# LA_0088 LA_T_6181183 - - bonafide
# LA_0088 LA_T_6271185 - - bonafide
# LA_0088 LA_T_6541032 - - bonafide
# LA_0088 LA_T_6546868 - - bonafide
# LA_0088 LA_T_6630920 - - bonafide
# LA_0088 LA_T_6632904 - - bonafide
# LA_0088 LA_T_6816591 - - bonafide
# LA_0088 LA_T_6910683 - - bonafide
# LA_0088 LA_T_7087021 - - bonafide
# LA_0088 LA_T_7121055 - - bonafide
# LA_0088 LA_T_7140181 - - bonafide
# LA_0088 LA_T_7220961 - - bonafide
# LA_0088 LA_T_7310629 - - bonafide
# LA_0088 LA_T_7432530 - - bonafide
# LA_0088 LA_T_7441106 - - bonafide
# LA_0088 LA_T_7465137 - - bonafide
# LA_0088 LA_T_7466245 - - bonafide
# LA_0088 LA_T_7597238 - - bonafide
# LA_0088 LA_T_7667992 - - bonafide
# LA_0088 LA_T_7761175 - - bonafide
# LA_0088 LA_T_7833340 - - bonafide
# LA_0088 LA_T_7976744 - - bonafide
# LA_0088 LA_T_7985597 - - bonafide
# LA_0088 LA_T_8002835 - - bonafide
# LA_0088 LA_T_8083939 - - bonafide
# LA_0088 LA_T_8097695 - - bonafide
# LA_0088 LA_T_8111589 - - bonafide
# LA_0088 LA_T_8174772 - - bonafide
# LA_0088 LA_T_8176264 - - bonafide
# LA_0088 LA_T_8211262 - - bonafide
# LA_0088 LA_T_8214944 - - bonafide
# LA_0088 LA_T_8275432 - - bonafide
# LA_0088 LA_T_8350634 - - bonafide
# LA_0088 LA_T_8406833 - - bonafide
# LA_0088 LA_T_8536928 - - bonafide
# LA_0088 LA_T_8543558 - - bonafide
# LA_0088 LA_T_8576608 - - bonafide
# LA_0088 LA_T_8595870 - - bonafide
# LA_0088 LA_T_8710866 - - bonafide
# LA_0088 LA_T_8726287 - - bonafide
# LA_0088 LA_T_8856169 - - bonafide
# LA_0088 LA_T_8880327 - - bonafide
# LA_0088 LA_T_8992190 - - bonafide
# LA_0088 LA_T_8993559 - - bonafide
# LA_0088 LA_T_9038660 - - bonafide
# LA_0088 LA_T_9047102 - - bonafide
# LA_0088 LA_T_9229570 - - bonafide
# LA_0088 LA_T_9234278 - - bonafide
# LA_0088 LA_T_9369650 - - bonafide
# LA_0088 LA_T_9469062 - - bonafide
# LA_0088 LA_T_9469286 - - bonafide
# LA_0088 LA_T_9474664 - - bonafide
# LA_0088 LA_T_9712979 - - bonafide
# LA_0088 LA_T_9754081 - - bonafide
# LA_0088 LA_T_9789080 - - bonafide
# LA_0088 LA_T_9793995 - - bonafide
# LA_0088 LA_T_9881187 - - bonafide
# LA_0088 LA_T_9937911 - - bonafide
# LA_0089 LA_T_1000406 - - bonafide
# LA_0089 LA_T_1182856 - - bonafide
# LA_0089 LA_T_1208112 - - bonafide
# LA_0089 LA_T_1222609 - - bonafide
# LA_0089 LA_T_1276415 - - bonafide
# LA_0089 LA_T_1325649 - - bonafide
# LA_0089 LA_T_1392484 - - bonafide
# LA_0089 LA_T_1473061 - - bonafide
# LA_0089 LA_T_1543826 - - bonafide
# LA_0089 LA_T_1573354 - - bonafide
# LA_0089 LA_T_1661773 - - bonafide
# LA_0089 LA_T_1662696 - - bonafide
# LA_0089 LA_T_1691949 - - bonafide
# LA_0089 LA_T_1716742 - - bonafide
# LA_0089 LA_T_1869525 - - bonafide
# LA_0089 LA_T_1870772 - - bonafide
# LA_0089 LA_T_2012289 - - bonafide
# LA_0089 LA_T_2192287 - - bonafide
# LA_0089 LA_T_2201500 - - bonafide
# LA_0089 LA_T_2272655 - - bonafide
# LA_0089 LA_T_2388783 - - bonafide
# LA_0089 LA_T_2582808 - - bonafide
# LA_0089 LA_T_2598025 - - bonafide
# LA_0089 LA_T_2599995 - - bonafide
# LA_0089 LA_T_2715624 - - bonafide
# LA_0089 LA_T_2720806 - - bonafide
# LA_0089 LA_T_2746439 - - bonafide
# LA_0089 LA_T_2775248 - - bonafide
# LA_0089 LA_T_2804125 - - bonafide
# LA_0089 LA_T_2857315 - - bonafide
# LA_0089 LA_T_2993376 - - bonafide
# LA_0089 LA_T_3045749 - - bonafide
# LA_0089 LA_T_3058443 - - bonafide
# LA_0089 LA_T_3083581 - - bonafide
# LA_0089 LA_T_3153194 - - bonafide
# LA_0089 LA_T_3175127 - - bonafide
# LA_0089 LA_T_3204342 - - bonafide
# LA_0089 LA_T_3304535 - - bonafide
# LA_0089 LA_T_3380327 - - bonafide
# LA_0089 LA_T_3396974 - - bonafide
# LA_0089 LA_T_3426616 - - bonafide
# LA_0089 LA_T_3447201 - - bonafide
# LA_0089 LA_T_3877061 - - bonafide
# LA_0089 LA_T_3884115 - - bonafide
# LA_0089 LA_T_3913892 - - bonafide
# LA_0089 LA_T_3967178 - - bonafide
# LA_0089 LA_T_4015268 - - bonafide
# LA_0089 LA_T_4055913 - - bonafide
# LA_0089 LA_T_4090060 - - bonafide
# LA_0089 LA_T_4224058 - - bonafide
# LA_0089 LA_T_4290789 - - bonafide
# LA_0089 LA_T_4300273 - - bonafide
# LA_0089 LA_T_4365712 - - bonafide
# LA_0089 LA_T_4436477 - - bonafide
# LA_0089 LA_T_4529370 - - bonafide
# LA_0089 LA_T_4557107 - - bonafide
# LA_0089 LA_T_4657357 - - bonafide
# LA_0089 LA_T_4707993 - - bonafide
# LA_0089 LA_T_4760367 - - bonafide
# LA_0089 LA_T_4842455 - - bonafide
# LA_0089 LA_T_4853062 - - bonafide
# LA_0089 LA_T_5015893 - - bonafide
# LA_0089 LA_T_5029038 - - bonafide
# LA_0089 LA_T_5098034 - - bonafide
# LA_0089 LA_T_5242457 - - bonafide
# LA_0089 LA_T_5439881 - - bonafide
# LA_0089 LA_T_5511230 - - bonafide
# LA_0089 LA_T_5565624 - - bonafide
# LA_0089 LA_T_5572362 - - bonafide
# LA_0089 LA_T_5669661 - - bonafide
# LA_0089 LA_T_5702907 - - bonafide
# LA_0089 LA_T_5757722 - - bonafide
# LA_0089 LA_T_6017121 - - bonafide
# LA_0089 LA_T_6017674 - - bonafide
# LA_0089 LA_T_6082276 - - bonafide
# LA_0089 LA_T_6144368 - - bonafide
# LA_0089 LA_T_6190702 - - bonafide
# LA_0089 LA_T_6212674 - - bonafide
# LA_0089 LA_T_6324213 - - bonafide
# LA_0089 LA_T_6432468 - - bonafide
# LA_0089 LA_T_6566146 - - bonafide
# LA_0089 LA_T_6594586 - - bonafide
# LA_0089 LA_T_6627080 - - bonafide
# LA_0089 LA_T_6663907 - - bonafide
# LA_0089 LA_T_6760264 - - bonafide
# LA_0089 LA_T_6839158 - - bonafide
# LA_0089 LA_T_6869854 - - bonafide
# LA_0089 LA_T_6961644 - - bonafide
# LA_0089 LA_T_6979533 - - bonafide
# LA_0089 LA_T_7070241 - - bonafide
# LA_0089 LA_T_7084634 - - bonafide
# LA_0089 LA_T_7089329 - - bonafide
# LA_0089 LA_T_7164335 - - bonafide
# LA_0089 LA_T_7279776 - - bonafide
# LA_0089 LA_T_7303315 - - bonafide
# LA_0089 LA_T_7429069 - - bonafide
# LA_0089 LA_T_7473658 - - bonafide
# LA_0089 LA_T_7490764 - - bonafide
# LA_0089 LA_T_7512717 - - bonafide
# LA_0089 LA_T_7558374 - - bonafide
# LA_0089 LA_T_7608685 - - bonafide
# LA_0089 LA_T_7737217 - - bonafide
# LA_0089 LA_T_7814112 - - bonafide
# LA_0089 LA_T_7915229 - - bonafide
# LA_0089 LA_T_7958352 - - bonafide
# LA_0089 LA_T_8111539 - - bonafide
# LA_0089 LA_T_8135846 - - bonafide
# LA_0089 LA_T_8172146 - - bonafide
# LA_0089 LA_T_8305834 - - bonafide
# LA_0089 LA_T_8430551 - - bonafide
# LA_0089 LA_T_8461963 - - bonafide
# LA_0089 LA_T_8533509 - - bonafide
# LA_0089 LA_T_8636985 - - bonafide
# LA_0089 LA_T_8811170 - - bonafide
# LA_0089 LA_T_8846765 - - bonafide
# LA_0089 LA_T_8866822 - - bonafide
# LA_0089 LA_T_8914289 - - bonafide
# LA_0089 LA_T_8927591 - - bonafide
# LA_0089 LA_T_8955767 - - bonafide
# LA_0089 LA_T_9162137 - - bonafide
# LA_0089 LA_T_9162513 - - bonafide
# LA_0089 LA_T_9177970 - - bonafide
# LA_0089 LA_T_9194689 - - bonafide
# LA_0089 LA_T_9270440 - - bonafide
# LA_0089 LA_T_9363134 - - bonafide
# LA_0089 LA_T_9389215 - - bonafide
# LA_0089 LA_T_9460886 - - bonafide
# LA_0089 LA_T_9573877 - - bonafide
# LA_0089 LA_T_9587918 - - bonafide
# LA_0089 LA_T_9773614 - - bonafide
# LA_0089 LA_T_9860699 - - bonafide
# ...
# LA_0096 LA_T_4567574 - A06 spoof
# LA_0096 LA_T_4612737 - A06 spoof
# LA_0096 LA_T_4704254 - A06 spoof
# LA_0096 LA_T_4711551 - A06 spoof
# LA_0096 LA_T_4801875 - A06 spoof
# LA_0096 LA_T_4839164 - A06 spoof
# LA_0096 LA_T_4840120 - A06 spoof
# LA_0096 LA_T_5071368 - A06 spoof
# LA_0096 LA_T_5145304 - A06 spoof
# LA_0096 LA_T_5153670 - A06 spoof
# LA_0096 LA_T_5174487 - A06 spoof
# LA_0096 LA_T_5261295 - A06 spoof
# LA_0096 LA_T_5382276 - A06 spoof
# LA_0096 LA_T_5432245 - A06 spoof
# LA_0096 LA_T_5444018 - A06 spoof
# LA_0096 LA_T_5455299 - A06 spoof
# LA_0096 LA_T_5628551 - A06 spoof
# LA_0096 LA_T_5645746 - A06 spoof
# LA_0096 LA_T_5656534 - A06 spoof
# LA_0096 LA_T_5812238 - A06 spoof
# LA_0096 LA_T_5861516 - A06 spoof
# LA_0096 LA_T_5872666 - A06 spoof
# LA_0096 LA_T_5886782 - A06 spoof
# LA_0096 LA_T_5939365 - A06 spoof
# LA_0096 LA_T_5951648 - A06 spoof
# LA_0096 LA_T_6009317 - A06 spoof
# LA_0096 LA_T_6041460 - A06 spoof
# LA_0096 LA_T_6152543 - A06 spoof
# LA_0096 LA_T_6157285 - A06 spoof
# LA_0096 LA_T_6280861 - A06 spoof
# LA_0096 LA_T_6309904 - A06 spoof
# LA_0096 LA_T_6356124 - A06 spoof
# LA_0096 LA_T_6452034 - A06 spoof
# LA_0096 LA_T_6469530 - A06 spoof
# LA_0096 LA_T_6472494 - A06 spoof
# LA_0096 LA_T_6534698 - A06 spoof
# LA_0096 LA_T_6550787 - A06 spoof
# LA_0096 LA_T_6822716 - A06 spoof
# LA_0096 LA_T_6828756 - A06 spoof
# LA_0096 LA_T_6840879 - A06 spoof
# LA_0096 LA_T_6901451 - A06 spoof
# LA_0096 LA_T_6910450 - A06 spoof
# LA_0096 LA_T_6977624 - A06 spoof
# LA_0096 LA_T_7041500 - A06 spoof
# LA_0096 LA_T_7093519 - A06 spoof
# LA_0096 LA_T_7119459 - A06 spoof
# LA_0096 LA_T_7151361 - A06 spoof
# LA_0096 LA_T_7268838 - A06 spoof
# LA_0096 LA_T_7292691 - A06 spoof
# LA_0096 LA_T_7375751 - A06 spoof
# LA_0096 LA_T_7402798 - A06 spoof
# LA_0096 LA_T_7417453 - A06 spoof
# LA_0096 LA_T_7623882 - A06 spoof
# LA_0096 LA_T_7678606 - A06 spoof
# LA_0096 LA_T_7680224 - A06 spoof
# LA_0096 LA_T_7694681 - A06 spoof
# LA_0096 LA_T_7709894 - A06 spoof
# LA_0096 LA_T_7715241 - A06 spoof
# LA_0096 LA_T_7784353 - A06 spoof
# LA_0096 LA_T_7822940 - A06 spoof
# LA_0096 LA_T_7849882 - A06 spoof
# LA_0096 LA_T_7855058 - A06 spoof
# LA_0096 LA_T_7954277 - A06 spoof
# LA_0096 LA_T_7994386 - A06 spoof
# LA_0096 LA_T_8031896 - A06 spoof
# LA_0096 LA_T_8216504 - A06 spoof
# LA_0096 LA_T_8347819 - A06 spoof
# LA_0096 LA_T_8351903 - A06 spoof
# LA_0096 LA_T_8358018 - A06 spoof
# LA_0096 LA_T_8375632 - A06 spoof
# LA_0096 LA_T_8503056 - A06 spoof
# LA_0096 LA_T_8503598 - A06 spoof
# LA_0096 LA_T_8511448 - A06 spoof
# LA_0096 LA_T_8517136 - A06 spoof
# LA_0096 LA_T_8585187 - A06 spoof
# LA_0096 LA_T_8597736 - A06 spoof
# LA_0096 LA_T_8612307 - A06 spoof
# LA_0096 LA_T_8652490 - A06 spoof
# LA_0096 LA_T_8659550 - A06 spoof
# LA_0096 LA_T_8764750 - A06 spoof
# LA_0096 LA_T_8781092 - A06 spoof
# LA_0096 LA_T_8781445 - A06 spoof
# LA_0096 LA_T_8783241 - A06 spoof
# LA_0096 LA_T_8806834 - A06 spoof
# LA_0096 LA_T_8817709 - A06 spoof
# LA_0096 LA_T_8883143 - A06 spoof
# LA_0096 LA_T_9022705 - A06 spoof
# LA_0096 LA_T_9023352 - A06 spoof
# LA_0096 LA_T_9034612 - A06 spoof
# LA_0096 LA_T_9074044 - A06 spoof
# LA_0096 LA_T_9076734 - A06 spoof
# LA_0096 LA_T_9155097 - A06 spoof
# LA_0096 LA_T_9179892 - A06 spoof
# LA_0096 LA_T_9328670 - A06 spoof
# LA_0096 LA_T_9331964 - A06 spoof
# LA_0096 LA_T_9351062 - A06 spoof
# LA_0096 LA_T_9394839 - A06 spoof
# LA_0096 LA_T_9447425 - A06 spoof
# LA_0096 LA_T_9452373 - A06 spoof
# LA_0096 LA_T_9460748 - A06 spoof
# LA_0096 LA_T_9509346 - A06 spoof
# LA_0096 LA_T_9536794 - A06 spoof
# LA_0096 LA_T_9548139 - A06 spoof
# LA_0096 LA_T_9592171 - A06 spoof
# LA_0096 LA_T_9599616 - A06 spoof
# LA_0096 LA_T_9682451 - A06 spoof
# LA_0096 LA_T_9705369 - A06 spoof
# LA_0096 LA_T_9810479 - A06 spoof
# LA_0096 LA_T_9815807 - A06 spoof
# LA_0096 LA_T_9859706 - A06 spoof
# LA_0096 LA_T_9859918 - A06 spoof
# LA_0096 LA_T_9865563 - A06 spoof
# LA_0097 LA_T_1114442 - A06 spoof
# LA_0097 LA_T_1212475 - A06 spoof
# LA_0097 LA_T_1362412 - A06 spoof
# LA_0097 LA_T_1383068 - A06 spoof
# LA_0097 LA_T_1446049 - A06 spoof
# LA_0097 LA_T_1460207 - A06 spoof
# LA_0097 LA_T_1492361 - A06 spoof
# LA_0097 LA_T_1568153 - A06 spoof
# LA_0097 LA_T_1581266 - A06 spoof
# LA_0097 LA_T_1584720 - A06 spoof
# LA_0097 LA_T_1597794 - A06 spoof
# LA_0097 LA_T_1602347 - A06 spoof
# LA_0097 LA_T_1621439 - A06 spoof
# LA_0097 LA_T_1710175 - A06 spoof
# LA_0097 LA_T_1748910 - A06 spoof
# LA_0097 LA_T_1753295 - A06 spoof
# LA_0097 LA_T_1777257 - A06 spoof
# LA_0097 LA_T_1830070 - A06 spoof
# LA_0097 LA_T_1836745 - A06 spoof
# LA_0097 LA_T_1966513 - A06 spoof
# LA_0097 LA_T_2070135 - A06 spoof
# LA_0097 LA_T_2120698 - A06 spoof
# LA_0097 LA_T_2155869 - A06 spoof
# LA_0097 LA_T_2201871 - A06 spoof
# LA_0097 LA_T_2237201 - A06 spoof
# LA_0097 LA_T_2315772 - A06 spoof
# LA_0097 LA_T_2317978 - A06 spoof
# LA_0097 LA_T_2365100 - A06 spoof
# LA_0097 LA_T_2424001 - A06 spoof
# LA_0097 LA_T_2462715 - A06 spoof
# LA_0097 LA_T_2517686 - A06 spoof
# LA_0097 LA_T_2547887 - A06 spoof
# LA_0097 LA_T_2561360 - A06 spoof
# LA_0097 LA_T_2562609 - A06 spoof
# LA_0097 LA_T_2598909 - A06 spoof
# LA_0097 LA_T_2671922 - A06 spoof
# LA_0097 LA_T_2681186 - A06 spoof
# LA_0097 LA_T_2684487 - A06 spoof
# LA_0097 LA_T_2687846 - A06 spoof
# LA_0097 LA_T_2809197 - A06 spoof
# LA_0097 LA_T_2940045 - A06 spoof
# LA_0097 LA_T_2998149 - A06 spoof
# LA_0097 LA_T_3104365 - A06 spoof
# LA_0097 LA_T_3116696 - A06 spoof
# LA_0097 LA_T_3203870 - A06 spoof
# LA_0097 LA_T_3209262 - A06 spoof
# LA_0097 LA_T_3215214 - A06 spoof
# LA_0097 LA_T_3230250 - A06 spoof
# LA_0097 LA_T_3330146 - A06 spoof
# LA_0097 LA_T_3345585 - A06 spoof
# LA_0097 LA_T_3394890 - A06 spoof
# LA_0097 LA_T_3407067 - A06 spoof
# LA_0097 LA_T_3457892 - A06 spoof
# LA_0097 LA_T_3458159 - A06 spoof
# LA_0097 LA_T_3497527 - A06 spoof
# LA_0097 LA_T_3508076 - A06 spoof
# LA_0097 LA_T_3674915 - A06 spoof
# LA_0097 LA_T_3923350 - A06 spoof
# LA_0097 LA_T_3987993 - A06 spoof
# LA_0097 LA_T_4062268 - A06 spoof
# LA_0097 LA_T_4072632 - A06 spoof
# LA_0097 LA_T_4102973 - A06 spoof
# LA_0097 LA_T_4155690 - A06 spoof
# LA_0097 LA_T_4172772 - A06 spoof
# LA_0097 LA_T_4223888 - A06 spoof
# LA_0097 LA_T_4243832 - A06 spoof
# LA_0097 LA_T_4244044 - A06 spoof
# LA_0097 LA_T_4297280 - A06 spoof
# LA_0097 LA_T_4376617 - A06 spoof
# LA_0097 LA_T_4386825 - A06 spoof
# LA_0097 LA_T_4461906 - A06 spoof
# LA_0097 LA_T_4480170 - A06 spoof
# LA_0097 LA_T_4503144 - A06 spoof
# LA_0097 LA_T_4547119 - A06 spoof
# LA_0097 LA_T_4562769 - A06 spoof
# LA_0097 LA_T_4574602 - A06 spoof
# LA_0097 LA_T_4602740 - A06 spoof
# LA_0097 LA_T_4667000 - A06 spoof
# LA_0097 LA_T_4686108 - A06 spoof
# LA_0097 LA_T_4750404 - A06 spoof
# LA_0097 LA_T_4858165 - A06 spoof
# LA_0097 LA_T_4907342 - A06 spoof
# LA_0097 LA_T_4914312 - A06 spoof
# LA_0097 LA_T_4930945 - A06 spoof
# LA_0097 LA_T_5018353 - A06 spoof
# LA_0097 LA_T_5018986 - A06 spoof
# LA_0097 LA_T_5021134 - A06 spoof
# LA_0097 LA_T_5024317 - A06 spoof
# LA_0097 LA_T_5025766 - A06 spoof
# LA_0097 LA_T_5209238 - A06 spoof
# LA_0097 LA_T_5217297 - A06 spoof
# LA_0097 LA_T_5263273 - A06 spoof
# LA_0097 LA_T_5280537 - A06 spoof
# LA_0097 LA_T_5365228 - A06 spoof
# LA_0097 LA_T_5370494 - A06 spoof
# LA_0097 LA_T_5469976 - A06 spoof
# LA_0097 LA_T_5502171 - A06 spoof
# LA_0097 LA_T_5556324 - A06 spoof
# LA_0097 LA_T_5702967 - A06 spoof
# LA_0097 LA_T_5717414 - A06 spoof
# LA_0097 LA_T_5787626 - A06 spoof
# LA_0097 LA_T_5794806 - A06 spoof
# LA_0097 LA_T_5807714 - A06 spoof
# LA_0097 LA_T_5913621 - A06 spoof
# LA_0097 LA_T_5987570 - A06 spoof
# LA_0097 LA_T_6005553 - A06 spoof
# LA_0097 LA_T_6022496 - A06 spoof
# LA_0097 LA_T_6086196 - A06 spoof
# LA_0097 LA_T_6107871 - A06 spoof
# LA_0097 LA_T_6118163 - A06 spoof
# LA_0097 LA_T_6149116 - A06 spoof
# LA_0097 LA_T_6168132 - A06 spoof
# LA_0097 LA_T_6185635 - A06 spoof
# LA_0097 LA_T_6339242 - A06 spoof
# LA_0097 LA_T_6409882 - A06 spoof
# LA_0097 LA_T_6432654 - A06 spoof
# LA_0097 LA_T_6447749 - A06 spoof
# LA_0097 LA_T_6448952 - A06 spoof
# LA_0097 LA_T_6491231 - A06 spoof
# LA_0097 LA_T_6511402 - A06 spoof
# LA_0097 LA_T_6554613 - A06 spoof
# LA_0097 LA_T_6682948 - A06 spoof
# LA_0097 LA_T_6717582 - A06 spoof
# LA_0097 LA_T_6811138 - A06 spoof
# LA_0097 LA_T_6828008 - A06 spoof
# LA_0097 LA_T_6859505 - A06 spoof
# LA_0097 LA_T_6886380 - A06 spoof
# LA_0097 LA_T_6962424 - A06 spoof
# LA_0097 LA_T_6966678 - A06 spoof
# LA_0097 LA_T_6967180 - A06 spoof
# LA_0097 LA_T_6967723 - A06 spoof
# LA_0097 LA_T_6982482 - A06 spoof
# LA_0097 LA_T_7002651 - A06 spoof
# LA_0097 LA_T_7005100 - A06 spoof
# LA_0097 LA_T_7010527 - A06 spoof
# LA_0097 LA_T_7045693 - A06 spoof
# LA_0097 LA_T_7068223 - A06 spoof
# LA_0097 LA_T_7105841 - A06 spoof
# LA_0097 LA_T_7123195 - A06 spoof
# LA_0097 LA_T_7515714 - A06 spoof
# LA_0097 LA_T_7517332 - A06 spoof
# LA_0097 LA_T_7584696 - A06 spoof
# LA_0097 LA_T_7588414 - A06 spoof
# LA_0097 LA_T_7724717 - A06 spoof
# LA_0097 LA_T_7767242 - A06 spoof
# LA_0097 LA_T_7805433 - A06 spoof
# LA_0097 LA_T_7830766 - A06 spoof
# LA_0097 LA_T_7873253 - A06 spoof
# LA_0097 LA_T_7881170 - A06 spoof
# LA_0097 LA_T_7978789 - A06 spoof
# LA_0097 LA_T_7992865 - A06 spoof
# LA_0097 LA_T_8051261 - A06 spoof
# LA_0097 LA_T_8052314 - A06 spoof
# LA_0097 LA_T_8059922 - A06 spoof
# LA_0097 LA_T_8078728 - A06 spoof
# LA_0097 LA_T_8091305 - A06 spoof
# LA_0097 LA_T_8154653 - A06 spoof
# LA_0097 LA_T_8168035 - A06 spoof
# LA_0097 LA_T_8175086 - A06 spoof
# LA_0097 LA_T_8255254 - A06 spoof
# LA_0097 LA_T_8278096 - A06 spoof
# LA_0097 LA_T_8306508 - A06 spoof
# LA_0097 LA_T_8367167 - A06 spoof
# LA_0097 LA_T_8369586 - A06 spoof
# LA_0097 LA_T_8401545 - A06 spoof
# LA_0097 LA_T_8428084 - A06 spoof
# LA_0097 LA_T_8557172 - A06 spoof
# LA_0097 LA_T_8642542 - A06 spoof
# LA_0097 LA_T_8650964 - A06 spoof
# LA_0097 LA_T_8781199 - A06 spoof
# LA_0097 LA_T_8854785 - A06 spoof
# LA_0097 LA_T_9047858 - A06 spoof
# LA_0097 LA_T_9087756 - A06 spoof
# LA_0097 LA_T_9285608 - A06 spoof
# LA_0097 LA_T_9329177 - A06 spoof
# LA_0097 LA_T_9339793 - A06 spoof
# LA_0097 LA_T_9405524 - A06 spoof
# LA_0097 LA_T_9547226 - A06 spoof
# LA_0097 LA_T_9639923 - A06 spoof
# LA_0097 LA_T_9819737 - A06 spoof
# LA_0097 LA_T_9841731 - A06 spoof
# LA_0097 LA_T_9920658 - A06 spoof
# LA_0097 LA_T_9929535 - A06 spoof
# LA_0097 LA_T_9941132 - A06 spoof
# LA_0097 LA_T_9953580 - A06 spoof
# LA_0097 LA_T_9958647 - A06 spoof
# LA_0098 LA_T_1053104 - A06 spoof
# LA_0098 LA_T_1057046 - A06 spoof
# LA_0098 LA_T_1129020 - A06 spoof
# LA_0098 LA_T_1216579 - A06 spoof
# LA_0098 LA_T_1240818 - A06 spoof
# LA_0098 LA_T_1299858 - A06 spoof
# LA_0098 LA_T_1494819 - A06 spoof
# LA_0098 LA_T_1530529 - A06 spoof
# LA_0098 LA_T_1538864 - A06 spoof
# LA_0098 LA_T_1547617 - A06 spoof
# LA_0098 LA_T_1591146 - A06 spoof
# LA_0098 LA_T_1637008 - A06 spoof
# LA_0098 LA_T_1648019 - A06 spoof
# LA_0098 LA_T_1683885 - A06 spoof
# LA_0098 LA_T_1779190 - A06 spoof
# LA_0098 LA_T_1793754 - A06 spoof
# LA_0098 LA_T_1878288 - A06 spoof
# LA_0098 LA_T_1909369 - A06 spoof
# LA_0098 LA_T_2000338 - A06 spoof
# LA_0098 LA_T_2031561 - A06 spoof
# LA_0098 LA_T_2042078 - A06 spoof
# LA_0098 LA_T_2120452 - A06 spoof
# LA_0098 LA_T_2164012 - A06 spoof
# LA_0098 LA_T_2226958 - A06 spoof
# LA_0098 LA_T_2227042 - A06 spoof
# LA_0098 LA_T_2306480 - A06 spoof
# LA_0098 LA_T_2347803 - A06 spoof
# LA_0098 LA_T_2352992 - A06 spoof
# LA_0098 LA_T_2357774 - A06 spoof
# LA_0098 LA_T_2458418 - A06 spoof
# LA_0098 LA_T_2479331 - A06 spoof
# LA_0098 LA_T_2501427 - A06 spoof
# LA_0098 LA_T_2601849 - A06 spoof
# LA_0098 LA_T_2624058 - A06 spoof
# LA_0098 LA_T_2636328 - A06 spoof
# LA_0098 LA_T_2656568 - A06 spoof
# LA_0098 LA_T_2703036 - A06 spoof
# LA_0098 LA_T_2748681 - A06 spoof
# LA_0098 LA_T_2766626 - A06 spoof
# LA_0098 LA_T_2772197 - A06 spoof
# LA_0098 LA_T_2782131 - A06 spoof
# LA_0098 LA_T_2782217 - A06 spoof
# LA_0098 LA_T_2800535 - A06 spoof
# LA_0098 LA_T_2825832 - A06 spoof
# LA_0098 LA_T_2855189 - A06 spoof
# LA_0098 LA_T_2915385 - A06 spoof
# LA_0098 LA_T_2924923 - A06 spoof
# LA_0098 LA_T_3027379 - A06 spoof
# LA_0098 LA_T_3147215 - A06 spoof
# LA_0098 LA_T_3241826 - A06 spoof
# LA_0098 LA_T_3258161 - A06 spoof
# LA_0098 LA_T_3286362 - A06 spoof
# LA_0098 LA_T_3286480 - A06 spoof
# LA_0098 LA_T_3392426 - A06 spoof
# LA_0098 LA_T_3415457 - A06 spoof
# LA_0098 LA_T_3442478 - A06 spoof
# LA_0098 LA_T_3471825 - A06 spoof
# LA_0098 LA_T_3476616 - A06 spoof
# LA_0098 LA_T_3502034 - A06 spoof
# LA_0098 LA_T_3511602 - A06 spoof
# LA_0098 LA_T_3588087 - A06 spoof
# LA_0098 LA_T_3703225 - A06 spoof
# LA_0098 LA_T_3712096 - A06 spoof
# LA_0098 LA_T_3794886 - A06 spoof
# LA_0098 LA_T_3813363 - A06 spoof
# LA_0098 LA_T_3834596 - A06 spoof
# LA_0098 LA_T_3861578 - A06 spoof
# LA_0098 LA_T_3889902 - A06 spoof
# LA_0098 LA_T_3947124 - A06 spoof
# LA_0098 LA_T_4083512 - A06 spoof
# LA_0098 LA_T_4154636 - A06 spoof
# LA_0098 LA_T_4156985 - A06 spoof
# LA_0098 LA_T_4187934 - A06 spoof
# LA_0098 LA_T_4248488 - A06 spoof
# LA_0098 LA_T_4344913 - A06 spoof
# LA_0098 LA_T_4382452 - A06 spoof
# LA_0098 LA_T_4399707 - A06 spoof
# LA_0098 LA_T_4461420 - A06 spoof
# LA_0098 LA_T_4467989 - A06 spoof
# LA_0098 LA_T_4476721 - A06 spoof
# LA_0098 LA_T_4532319 - A06 spoof
# LA_0098 LA_T_4546061 - A06 spoof
# LA_0098 LA_T_4661041 - A06 spoof
# LA_0098 LA_T_4666811 - A06 spoof
# LA_0098 LA_T_4669717 - A06 spoof
# LA_0098 LA_T_4782992 - A06 spoof
# LA_0098 LA_T_4790964 - A06 spoof
# LA_0098 LA_T_4888310 - A06 spoof
# LA_0098 LA_T_4991071 - A06 spoof
# LA_0098 LA_T_5021176 - A06 spoof
# LA_0098 LA_T_5039658 - A06 spoof
# LA_0098 LA_T_5039972 - A06 spoof
# LA_0098 LA_T_5046261 - A06 spoof
# LA_0098 LA_T_5057814 - A06 spoof
# LA_0098 LA_T_5300943 - A06 spoof
# LA_0098 LA_T_5546879 - A06 spoof
# LA_0098 LA_T_5754252 - A06 spoof
# LA_0098 LA_T_5856596 - A06 spoof
# LA_0098 LA_T_5884232 - A06 spoof
# LA_0098 LA_T_5901810 - A06 spoof
# LA_0098 LA_T_6018275 - A06 spoof
# LA_0098 LA_T_6023616 - A06 spoof
# LA_0098 LA_T_6037984 - A06 spoof
# LA_0098 LA_T_6084870 - A06 spoof
# LA_0098 LA_T_6104293 - A06 spoof
# LA_0098 LA_T_6125972 - A06 spoof
# LA_0098 LA_T_6132689 - A06 spoof
# LA_0098 LA_T_6173040 - A06 spoof
# LA_0098 LA_T_6191504 - A06 spoof
# LA_0098 LA_T_6250535 - A06 spoof
# LA_0098 LA_T_6270258 - A06 spoof
# LA_0098 LA_T_6318372 - A06 spoof
# LA_0098 LA_T_6502103 - A06 spoof
# LA_0098 LA_T_6558410 - A06 spoof
# LA_0098 LA_T_6595818 - A06 spoof
# LA_0098 LA_T_6644418 - A06 spoof
# LA_0098 LA_T_6653021 - A06 spoof
# LA_0098 LA_T_6715221 - A06 spoof
# LA_0098 LA_T_6751029 - A06 spoof
# LA_0098 LA_T_6838056 - A06 spoof
# LA_0098 LA_T_6888159 - A06 spoof
# LA_0098 LA_T_6904396 - A06 spoof
# LA_0098 LA_T_6910737 - A06 spoof
# LA_0098 LA_T_6982758 - A06 spoof
# LA_0098 LA_T_7088470 - A06 spoof
# LA_0098 LA_T_7088742 - A06 spoof
# LA_0098 LA_T_7126643 - A06 spoof
# LA_0098 LA_T_7141358 - A06 spoof
# LA_0098 LA_T_7271931 - A06 spoof
# LA_0098 LA_T_7323782 - A06 spoof
# LA_0098 LA_T_7387135 - A06 spoof
# LA_0098 LA_T_7466024 - A06 spoof
# LA_0098 LA_T_7614168 - A06 spoof
# LA_0098 LA_T_7622813 - A06 spoof
# LA_0098 LA_T_7696831 - A06 spoof
# LA_0098 LA_T_7700480 - A06 spoof
# LA_0098 LA_T_7713397 - A06 spoof
# LA_0098 LA_T_7743020 - A06 spoof
# LA_0098 LA_T_7785811 - A06 spoof
# LA_0098 LA_T_7798887 - A06 spoof
# LA_0098 LA_T_7846009 - A06 spoof
# LA_0098 LA_T_7894716 - A06 spoof
# LA_0098 LA_T_7904751 - A06 spoof
# LA_0098 LA_T_7929359 - A06 spoof
# LA_0098 LA_T_7975984 - A06 spoof
# LA_0098 LA_T_8098268 - A06 spoof
# LA_0098 LA_T_8121646 - A06 spoof
# LA_0098 LA_T_8148012 - A06 spoof
# LA_0098 LA_T_8182129 - A06 spoof
# LA_0098 LA_T_8231122 - A06 spoof
# LA_0098 LA_T_8273353 - A06 spoof
# LA_0098 LA_T_8298614 - A06 spoof
# LA_0098 LA_T_8361423 - A06 spoof
# LA_0098 LA_T_8367117 - A06 spoof
# LA_0098 LA_T_8406170 - A06 spoof
# LA_0098 LA_T_8495510 - A06 spoof
# LA_0098 LA_T_8507676 - A06 spoof
# LA_0098 LA_T_8545170 - A06 spoof
# LA_0098 LA_T_8575046 - A06 spoof
# LA_0098 LA_T_8577208 - A06 spoof
# LA_0098 LA_T_8682667 - A06 spoof
# LA_0098 LA_T_8728304 - A06 spoof
# LA_0098 LA_T_8741286 - A06 spoof
# LA_0098 LA_T_8741491 - A06 spoof
# LA_0098 LA_T_8757076 - A06 spoof
# LA_0098 LA_T_8769562 - A06 spoof
# LA_0098 LA_T_8773439 - A06 spoof
# LA_0098 LA_T_8805612 - A06 spoof
# LA_0098 LA_T_8834650 - A06 spoof
# LA_0098 LA_T_8943168 - A06 spoof
# LA_0098 LA_T_8955640 - A06 spoof
# LA_0098 LA_T_9129364 - A06 spoof
# LA_0098 LA_T_9294450 - A06 spoof
# LA_0098 LA_T_9309916 - A06 spoof
# LA_0098 LA_T_9342202 - A06 spoof
# LA_0098 LA_T_9345362 - A06 spoof
# LA_0098 LA_T_9413366 - A06 spoof
# LA_0098 LA_T_9506621 - A06 spoof
# LA_0098 LA_T_9550569 - A06 spoof
# LA_0098 LA_T_9582904 - A06 spoof
# LA_0098 LA_T_9623506 - A06 spoof
# LA_0098 LA_T_9717580 - A06 spoof
# LA_0098 LA_T_9779814 - A06 spoof
# LA_0098 LA_T_9783312 - A06 spoof
# LA_0098 LA_T_9839348 - A06 spoof
# LA_0098 LA_T_9982036 - A06 spoof

# %%
# %cat /Users/savin/Omdena-Projects/Audioshield/data_train/README.LA.txt
# Out:
# =====================================================================================================
# ASVspoof 2019: The 3rd Automatic Speaker Verification Spoofing and Countermeasures Challenge database
#
# Logical access (LA)
# =====================================================================================================
#
#
# 1. Directory Structure
# _______________________
#
#   --> LA
#           --> ASVspoof2019_LA_asv_protocols
#           --> ASVspoof2019_LA_asv_scores
# 	  --> ASVspoof2019_LA_cm_protocols
#           --> ASVspoof2019_LA_dev
#           --> ASVspoof2019_LA_eval
# 	  --> ASVspoof2019_LA_train
# 	  --> README.LA.txt
#
#
# 2. Description of the audio files
# _________________________________
#
#    ASVspoof2019_LA_train, ASVspoof2019_LA_dev, and ASVspoof2019_LA_eval contain audio files for training, development, and evaluation
#    (LA_T_*.flac, LA_D_*.flac, and LA_E_*.flac, respectively). ASVspoof2019_PA_dev, and ASVspoof2019_PA_eval contain audio files to enroll ASV system. The audio files in the directories are in the flac format.
#    The sampling rate is 16 kHz, and stored in 16-bit.
#
#
# 3. Description of the protocols
# _______________________________
#
# CM protocols:
#
#    ASVspoof2019_LA_cm_protocols contains protocol files in ASCII format for ASVspoof countermeasures:
#
#    ASVspoof2019.LA.cm.train.trn.txt: training file list
#    ASVspoof2019.LA.cm.dev.trl.txt: development trials
#    ASVspoof2019.LA.cm.eval.trl.txt: evaluation trials
#
#    Each column of the protocol is formatted as:
#
#    SPEAKER_ID AUDIO_FILE_NAME - SYSTEM_ID KEY
#
#    	1) SPEAKER_ID: 		LA_****, a 4-digit speaker ID
#    	2) AUDIO_FILE_NAME: 	LA_****, name of the audio file
#    	3) SYSTEM_ID: 		ID of the speech spoofing system (A01 - A19),  or, for bonafide speech SYSTEM-ID is left blank ('-')
#    	4) -: 			This column is NOT used for LA.
# 	5) KEY: 		'bonafide' for genuine speech, or, 'spoof' for spoofing speech
#
#    Note that:
#
#    	1) the third column is left blank (-) to make the structure coherent with physical access file list;
#    	2) Brief description on LA spoofing systems, where TTS and VC denote text-to-speech and voice-conversion systems:
#
#         A01	TTS	neural waveform model
#         A02	TTS	vocoder
#         A03	TTS	vocoder
#         A04	TTS	waveform concatenation
#         A05	VC	vocoder
#         A06	VC	spectral filtering
#
#         A07	TTS	vocoder+GAN
#         A08	TTS	neural waveform
#         A09	TTS	vocoder
#         A10	TTS	neural waveform
#         A11	TTS	griffin lim
#         A12	TTS	neural waveform
#         A13	TTS_VC	waveform concatenation+waveform filtering
#         A14	TTS_VC	vocoder
#         A15	TTS_VC	neural waveform
#         A16	TTS	waveform concatenation
#         A17	VC	waveform filtering
#         A18	VC	vocoder
#         A19	VC	spectral filtering
#
# ASV protocols:
#
#    ASVspoof2019_LA_asv_protocols contains the protocol files for ASV system
#
# 	ASVspoof2019.LA.asv.<1>.<2>.<3>.txt
# 	where
# 	<1> is either 'dev' or 'eval' based on whether the files describe the development or evaluation protocol,
# 	<2> ie either 'male (m)' or 'female (f)' separating the genders from each other or 'gender independent (gi)'
# 	    contains trials for both genders (male trials followed by female trials),
# 	<3> is either 'trl' or 'trn' (trl = trial list, trn = speaker enrollment list).
#
# 	Trial (trl) file format for LA scenario:
# 	1st column: claimed speaker ID
# 	2nd column: test file ID
# 	3rd column: spoof attack ID (or 'bonafide' if the speech is not spoofed)
# 	4th column: key (target = target trial, nontarget = impostor trial, spoof = spoofing attack)
#
# 	Enrollment (trn) file format:
# 	1st column: ID of enrolled speaker
# 	2nd column: IDs of files used in the enrollment separated by commas
#
#
# 4. Baseline ASV scores
# ______________________
#
#    ASVspoof2019_LA_asv_scores contains the scores calculated by a baseline ASV system for t-DCF evaluation
#
#    	ASVspoof2019.LA.asv.dev.gi.trl.scores.txt:  scores given by the ASV system for development set data
#    	ASVspoof2019.LA.asv.eval.gi.trl.scores.txt: scores given by the ASV system for evaluation set data
#
#    Each column is formatted as:
#
#    CM_KEY ASV_KEY SCORES
#
#    	1) CM_KEY: 		'bonafide' for genuine speech, or, the ID of the spoofing attack (A01 - A19)
#    	2) ASV_KEY: 		'target' for claimed speaker, or, 'nontarget' for impostor speaker, or, 'spoof' for spoofing speech
#    	3) SCORES: 		similarity score value
#
# -------------------------------------------------------------------------------------------------------------------------------------

# %%
# Listing a small list of files in the training folder
# %ls /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1*
# Out:
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1000137.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1000406.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1000648.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1000824.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1001074.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1001114.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1001169.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1001718.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1001871.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1002656.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1003665.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1004407.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1004631.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1004644.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1005349.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1006715.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1006969.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1007217.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1007283.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1007408.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1007571.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1007615.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1007663.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1007914.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1008492.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1009193.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1010025.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1010137.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1010799.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1010949.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1011022.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1011221.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1011920.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1012129.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1012583.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1013068.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1013549.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1013597.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1014095.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1014341.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1015917.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1016062.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1016803.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1017036.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1017164.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1017249.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1017386.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1018227.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1019645.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1021310.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1021749.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1021789.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1021790.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1022109.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1022551.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1023546.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1023667.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1024889.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1025067.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1025399.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1025525.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1026006.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1026106.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1026130.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1026727.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1026765.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1027268.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1028046.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1028533.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1029007.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1029184.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1029621.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1029929.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1030180.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1030482.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1030559.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1030843.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1031233.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1031792.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1032064.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1032079.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1032598.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1033159.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1033197.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1033243.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1033465.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1033664.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1034027.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1034308.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1034356.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1034416.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1034552.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1034923.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1035039.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1035222.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1035981.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1036415.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1036683.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1036998.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1037573.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1037774.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1037807.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1037879.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1038078.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1038101.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1038282.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1039087.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1039152.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1039167.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1039538.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1039703.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1040088.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1040732.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1041151.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1041400.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1041465.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1041717.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1042175.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1042549.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1042958.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1042969.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1042985.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1043044.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1044167.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1044186.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1044202.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1044344.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1044512.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1044749.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1045294.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1045333.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1045827.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1045996.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1046090.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1046563.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1047588.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1049021.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1049212.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1049794.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1049856.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1050008.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1050944.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1050952.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1051161.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1051226.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1051229.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1051754.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1051843.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1052701.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1052790.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1053104.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1053141.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1053692.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1054176.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1054204.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1054206.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1055109.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1055655.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1056013.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1056344.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1056690.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1056709.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1057046.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1057453.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1057673.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1058915.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1059252.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1059324.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1059937.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1060413.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1060760.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1060877.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1061562.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1061575.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1062461.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1063619.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1064423.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1064484.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1064797.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1065455.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1065893.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1066145.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1066374.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1066444.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1067322.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1067553.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1067682.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1067825.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1068454.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1068558.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1069045.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1069321.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1069388.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1069506.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1070377.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1071120.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1071128.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1071183.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1072331.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1072591.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1072646.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1073026.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1074433.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1074765.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1075018.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1075258.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1075302.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1075556.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1076032.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1076210.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1076834.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1076943.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1077459.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1077649.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1078395.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1078480.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1078605.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1078877.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1078988.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1079079.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1079147.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1079418.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1079836.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1080623.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1081004.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1081350.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1081570.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1081692.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1081824.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1081925.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1082540.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1083055.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1083769.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1083978.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1084255.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1085622.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1085646.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1085704.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1085866.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1085885.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1086559.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1087286.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1087556.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1087609.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1087632.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1087807.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1087973.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1088154.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1088160.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1088332.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1088656.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1090341.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1090563.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1090723.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1090807.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1090966.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1091140.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1091414.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1091653.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1091875.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1092005.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1092563.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1093716.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1094085.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1095031.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1095420.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1095850.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1096586.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1096613.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1097088.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1097440.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1097604.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1097864.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1098525.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1098857.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1099214.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1099910.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1100114.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1100207.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1100628.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1101479.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1103057.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1103144.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1103401.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1103630.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1103710.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1103936.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1107106.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1107524.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1107565.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1107670.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1108020.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1108702.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1108824.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1108840.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1109145.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1109278.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1109462.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1109788.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1109955.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1110572.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1110673.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1110914.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1111107.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1111764.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1113457.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1113931.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1113976.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1114442.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1114980.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1115054.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1115237.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1116030.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1116175.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1116187.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1116345.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1116382.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1117199.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1117664.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1119401.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1119555.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1119789.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1119899.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1120474.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1120592.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1120947.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1121656.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1121855.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1121974.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1122058.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1122769.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1122961.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1123577.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1124738.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1124839.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1125418.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1126002.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1126118.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1126222.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1126227.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1126698.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1127197.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1128284.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1128453.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1128464.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1128865.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1129020.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1129547.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1129923.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1130054.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1130076.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1130675.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1130893.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1130924.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1130943.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1131312.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1131555.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1132062.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1132403.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1132475.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1133512.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1133929.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1134314.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1134598.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1134909.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1134997.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1135747.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1136677.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1136756.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1137226.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1137533.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1137883.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1137942.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1138215.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1138237.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1139785.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1140654.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1141342.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1141725.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1142053.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1142427.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1142757.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1143756.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1145282.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1145741.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1146351.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1146868.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1146967.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1147364.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1147552.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1147556.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1148129.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1148175.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1148535.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1148654.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1148844.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1148993.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1149087.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1149135.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1149145.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1149443.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1150028.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1150653.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1150787.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1150895.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1151332.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1151489.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1151825.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1152016.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1152387.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1152394.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1152870.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1153016.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1153198.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1153405.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1153489.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1153987.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1154440.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1155093.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1155184.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1156100.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1156513.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1156774.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1157103.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1157756.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1158098.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1158271.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1158406.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1160090.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1160239.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1161442.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1161445.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1161683.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1161711.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1161788.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1161958.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1162278.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1162361.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1162877.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1162918.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1163771.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1163956.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1163987.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1164518.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1164775.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1165581.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1165875.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1166468.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1167339.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1167346.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1167616.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1167878.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1167935.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1168059.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1168427.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1168531.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1168781.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1171266.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1171310.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1171346.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1172893.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1173050.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1173157.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1173561.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1173816.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1174772.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1175148.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1175418.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1175560.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1176596.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1176618.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1177155.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1177471.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1178793.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1178897.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1178948.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1179505.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1179520.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1180374.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1180379.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1180816.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1180971.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1180981.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1181129.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1181374.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1181809.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1181838.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1182166.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1182547.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1182856.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1183321.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1183718.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1184273.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1184541.flac
# ...
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1936209.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1936706.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1937797.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1938160.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1939177.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1939554.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1939844.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1940419.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1940939.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1940982.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1941612.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1942388.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1942452.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1942931.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1943407.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1943560.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1944007.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1944179.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1944794.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1945118.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1945284.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1945759.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1946144.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1946682.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1946706.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1946710.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1947138.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1947289.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1948354.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1948575.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1949241.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1949444.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1949526.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1949866.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1950262.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1951175.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1951220.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1951326.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1952447.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1952524.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1952833.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1953088.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1953670.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1954200.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1955701.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1955840.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1955947.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1956054.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1957177.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1957408.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1957524.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1957538.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1957762.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1957871.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1958037.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1958041.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1958248.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1959047.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1959075.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1959178.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1960440.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1960567.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1961646.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1962079.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1962461.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1962837.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1963301.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1963397.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1963537.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1963829.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1964051.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1964416.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1964808.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1964816.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1965460.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1965565.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1965881.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1966513.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1967264.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1967315.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1968082.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1968330.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1968919.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1969578.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1970201.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1971369.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1971946.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1971994.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1972323.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1972607.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1972880.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1973113.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1973416.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1974078.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1975117.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1975290.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1975529.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1975563.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1976045.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1976302.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1976941.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1977590.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1979186.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1979527.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1979645.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1979697.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1979751.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1979880.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1980230.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1980518.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1980621.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1981310.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1981719.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1981942.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1982197.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1982403.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1982465.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1982975.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1983641.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1984466.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1984614.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1984878.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1984997.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1985258.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1985816.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1985854.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1986235.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1986344.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1986459.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1986518.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1986901.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1987048.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1987370.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1988186.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1989284.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1989869.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1989906.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1989982.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1990953.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1991672.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1991708.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1992769.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1993306.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1993493.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1993747.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1994274.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1994469.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1994843.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1996248.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1996389.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1996478.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1996489.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1996567.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1996644.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1996825.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1997043.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1997186.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1997192.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1997992.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1998317.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1998467.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1998626.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1999263.flac
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1999809.flac

# %% [markdown]
# We can see all the audio files in the .flac format here. FLAC (Free Lossless Audio Codec) is an audio coding format for lossless compression of digital audio. We can start to read some audio files from the train folder and do some visualization.

# %%
import glob
import numpy as np
import librosa
import librosa.display
from matplotlib import pyplot as plt
import IPython.display as ipd


# Audio data in the training, dev and eval  folder
train_fold = data_dir+'ASVspoof2019_LA_train/flac/*.flac'
dev_fold = data_dir+'ASVspoof2019_LA_dev/flac/*.flac'
eval_fold = data_dir+'ASVspoof2019_LA_eval/flac/*.flac'

# audio files
train_files = sorted(glob.glob(train_fold))
dev_files = sorted(glob.glob(dev_fold))
eval_files = sorted(glob.glob(eval_fold))

print(f"No. of audio files in the training folder: {len(train_files)}")
print(f"No. of audio files in the dev folder: {len(dev_files)}")
print(f"No. of audio files in the eval folder: {len(eval_files)}")
# Out:
# No. of audio files in the training folder: 25380
# No. of audio files in the dev folder: 24986
# No. of audio files in the eval folder: 71933

# %% [markdown]
# For the moment, let's concentrate on the data from the training folder. For the display of audio files, we will import 2 libraries here. Librosa is widely used to handle the audio data files.

# %% [markdown]
# ### Time Domain and Frequency domain visualization
# 1. Time series
# 2. Spectrogram
# 3. Mel spectrograms
#
# First we will look at the audio time series which is power plotted as a function of time. From the Fourier analysis, we know that each time series can be decomposed into it's frequency components using Fourier transform. This will allow us to undestand how much of a frequency content is present in each signal. If the signal frequency content is stationary, we can conduct a discrete Fourier transform. If the frequency inforamtion changes as a function of time, then we can divide the time series into short time segments and calculate their corresponing fourier transform to get a spectrogram (2D array of frequency and time).

# %%
# play the first audio file
ipd.Audio(train_files[0])

# Load a sample audio file as a time series and the sample rate of the audio
y, sr = librosa.load(train_files[0])

print(f"Sample length: {y.shape} and the sample rate: {sr}, duration :{y.shape[0]/sr:0.3f}s")

# Let's plot the audio time series
plt.plot(y)
plt.xlabel("No. of samples")
plt.ylabel("Power (a.u.)")
plt.title("Audio time series")
plt.show()
# Out:
# Sample length: (55134,) and the sample rate: 22050, duration :2.500s

# %%
# Now let's plot a spectrogram
# for this we will use an FFT with a window length of 2048 samples, hop_length = fft_size/4 which is the distance 
# between adjacent fft windows. The time segments can be overlapping to measure the change in the frequency component.

S = np.abs(librosa.stft(y, n_fft=2048, hop_length = 512)) # taking the amplitude of the FFT output
#plt.imshow(S, cmap='jet', aspect='auto', origin='lower')
#plt.show()

# Plot the transformed audio data
fig, ax = plt.subplots(figsize=(10, 5))
img = librosa.display.specshow(S,
                              x_axis='time',
                              y_axis='hz',
                              ax=ax)
ax.set_title('Spectogram', fontsize=15)
fig.colorbar(img, ax=ax, format=f'%0.2f')
plt.show()

# %%
# Let's look at the spectrogram in decibels
S_db = librosa.amplitude_to_db(S, ref=np.max)

# Plot the transformed audio data
fig, ax = plt.subplots(figsize=(10, 5))
img = librosa.display.specshow(S_db,
                              x_axis='time',
                              y_axis='hz',
                              ax=ax)
ax.set_title('Spectrogram in dB', fontsize=15)
fig.colorbar(img, ax=ax, format=f'%0.2f dB')
plt.show()

# %% [markdown]
# ### Mel Spectrogram
# All the frequnecy and time components can be clearly seen with the decibel units. Now let's see how the mel spectrogram looks like. Mel spectrogram is a spectrogram with its frequencies converted to Mel scale or basically in a log scale. For human beings, it is easy to understand the difference between frequencies at low frequencies than the high frequencies. Mel scale was introduced so that equal distance in pitch/frequency will sound equally distant to the listner.
# This can be easily computed using the "librosa.feature.melspectrogram" function. The input can be either a time series or a spectrogram. If given a time series, we need to specify the length of FFT and the overlap between time segments to calculate an STFT first. Let's do it directly from the time series as we will carry out that approach.

# %%
#S_mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128 * 2)

# Reading 2 seconds of data
S_mel = librosa.feature.melspectrogram(y=y[:int(sr*2.0)], sr=sr, n_mels=128)
S_db_mel = librosa.amplitude_to_db(S_mel, ref=np.max)

print(f"Mel spectrogram shape: {S_db_mel.shape}")
# Plot the transformed audio data
fig, ax = plt.subplots(figsize=(10, 5))
img = librosa.display.specshow(S_db_mel,
                              x_axis='time',
                              y_axis='mel',
                              ax=ax)
ax.set_title('Mel Spectrogram', fontsize=15)
fig.colorbar(img, ax=ax, format=f'%0.2f dB')
plt.show()
# Out:
# Mel spectrogram shape: (128, 87)

# %% [markdown]
# ### Data Preprocessing
# For modeling the data, let's take a random set of 5000 bonafide and spoof data for training. For that first we need to collect the label and filename information from the text file. Once we have that we can select a random set of 5000 audio files in both categories for training the model.

# %%
import pandas as pd

filepath = '/Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/'
# Funciton to extract information from the text file
def get_label_info(text_file):
    """
    Returns a pandas dataframe of label information
    Arguments:
    text_file: input text file with audio filename and labels
    """
    speaker_code = []
    filename = []
    spoof_code = []
    label = []
    with open(text_file,"r") as fh:
        for line in fh.readlines():
            str = line.split()
            speaker_code.append(str[0])
            filename.append(filepath + str[1] + '.flac') # adding the file extension for easy extraction
            spoof_code.append(str[3])
            label.append(str[4])
        fh.close()
    df = pd.DataFrame(data={'filename': filename, 'label': label, 'speaker_code': speaker_code, 'spoof_code': spoof_code})
    return df    

# text file containing information of the training data
label_file = '/Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_cm_protocols/ASVspoof2019.LA.cm.train.trn.txt'

df = get_label_info(label_file)
df.head()
# Out:
#                                             filename     label speaker_code  \
# 0  /Users/savin/Omdena-Projects/Audioshield/data_...  bonafide      LA_0079
# 1  /Users/savin/Omdena-Projects/Audioshield/data_...  bonafide      LA_0079
# 2  /Users/savin/Omdena-Projects/Audioshield/data_...  bonafide      LA_0079
# 3  /Users/savin/Omdena-Projects/Audioshield/data_...  bonafide      LA_0079
# 4  /Users/savin/Omdena-Projects/Audioshield/data_...  bonafide      LA_0079
#
#   spoof_code
# 0          -
# 1          -
# 2          -
# 3          -
# 4          -

# %%
# Now let's get some basic info out of the dataframe
df.describe()
# Out:
#                                                  filename  label speaker_code  \
# count                                               25380  25380        25380
# unique                                              25380      2           20
# top     /Users/savin/Omdena-Projects/Audioshield/data_...  spoof      LA_0089
# freq                                                    1  22800         1308
#
#        spoof_code
# count       25380
# unique          7
# top           A01
# freq         3800

# %% [markdown]
# As we can see there are 25380 unique audio files, 2 classes of labels, files corresponding to 20 speakers and 2 spoof codes. Let's see what the individual categories are.

# %%
df["label"].value_counts()
# Out:
# label
# spoof       22800
# bonafide     2580
# Name: count, dtype: int64

# %%
df["spoof_code"].value_counts()
# Out:
# spoof_code
# A01    3800
# A02    3800
# A03    3800
# A04    3800
# A05    3800
# A06    3800
# -      2580
# Name: count, dtype: int64

# %%
df["speaker_code"].value_counts()
# Out:
# speaker_code
# LA_0089    1308
# LA_0082    1308
# LA_0083    1308
# LA_0096    1308
# LA_0095    1308
# LA_0094    1308
# LA_0093    1308
# LA_0092    1308
# LA_0090    1243
# LA_0097    1243
# LA_0091    1243
# LA_0079    1243
# LA_0080    1243
# LA_0088    1243
# LA_0087    1243
# LA_0086    1243
# LA_0085    1243
# LA_0084    1243
# LA_0081    1243
# LA_0098    1243
# Name: count, dtype: int64

# %% [markdown]
# As we can see, the number of bonafide audio files in the training sample are way smaller compared to the number of spoofed files. The spoofed files have almost equal contributions from different spoofing techniques.
#
# To avoid bias during modeling of the datasets, let't take the whole bonafide dataset and equal number of spoofed files randomly sampled from the list we have.

# %%
# Get a list of data frame with the bonafide files and labels
bon_dat = df[df['label']=='bonafide'][["filename", "label"]]
bon_dat.value_counts()
# Out:
# filename                                                                                          label
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1000406.flac  bonafide    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_6839158.flac  bonafide    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_6926903.flac  bonafide    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_6927292.flac  bonafide    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_6935436.flac  bonafide    1
#                                                                                                              ..
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_3969759.flac  bonafide    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_3971937.flac  bonafide    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_3973421.flac  bonafide    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_3976536.flac  bonafide    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_9987202.flac  bonafide    1
# Name: count, Length: 2580, dtype: int64

# %%
# Get a random sample of the spoofed data from the list
spoof_dat = df[df['label']=='spoof'].sample(2580, axis=0)

#Let's take a look at the spoof code distribution
spoof_dat['spoof_code'].value_counts()
# Out:
# spoof_code
# A04    442
# A01    437
# A06    434
# A02    432
# A03    418
# A05    417
# Name: count, dtype: int64

# %% [markdown]
# So there are roughly equal contribution of audio files from different spoofing systems. This is to make sure that the model is robust to deepfake data from different spoofing methods.

# %%
# Just selecting the filenames and corresponding labels.
spoof_dat = spoof_dat[["filename", "label"]]
spoof_dat.value_counts()
# Out:
# filename                                                                                          label
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_1001718.flac  spoof    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_6862501.flac  spoof    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_6926739.flac  spoof    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_6927360.flac  spoof    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_6939571.flac  spoof    1
#                                                                                                           ..
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_3991957.flac  spoof    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_3996239.flac  spoof    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_4003925.flac  spoof    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_4010781.flac  spoof    1
# /Users/savin/Omdena-Projects/Audioshield/data_train/ASVspoof2019_LA_train/flac/LA_T_9987715.flac  spoof    1
# Name: count, Length: 2580, dtype: int64

# %% [markdown]
# Let's combine the spoof list and bonafide list to make a single list which can be used to create a training set and cross validation set

# %%
# concatenating data frames and shuffling them
fin_df = pd.concat([bon_dat, spoof_dat]).sample(frac=1,random_state = 42)
fin_df.head()
# Out:
#                                                 filename     label
# 2387   /Users/savin/Omdena-Projects/Audioshield/data_...  bonafide
# 12595  /Users/savin/Omdena-Projects/Audioshield/data_...     spoof
# 654    /Users/savin/Omdena-Projects/Audioshield/data_...  bonafide
# 1084   /Users/savin/Omdena-Projects/Audioshield/data_...  bonafide
# 2516   /Users/savin/Omdena-Projects/Audioshield/data_...  bonafide

# %%
fin_df['filename'].value_counts()
fin_df['label'].value_counts()
# Out:
# label
# bonafide    2580
# spoof       2580
# Name: count, dtype: int64

# %% [markdown]
# ####  Feature extraction
# Now we will extract the Mel spectrogram for all the training and CV audio files. But before that we have to make sure that the array dimensions of all the mel spectrograms are the same for feeding into CNN model. For that we need to investigate the duration of all the train and test files.

# %%
# Let's get the duration of all the files

def get_duration(df):
    """
    Function to get the duration of all the video files
    in the pandas data frame
    Returns: durations, numpy array
    argument:
    df : input pandas data frame
    """
    info = np.zeros(df.shape)
    for i in range(df.shape[0]):
        filename = df.iloc[i,0]
        y, sr = librosa.load(filename)
        info[i,:] = [y.shape[0]/sr, sr]
    return info

# Get the duration of all the files in the final data frame
info = get_duration(fin_df)
dur_files = info[:,0] # durations
sr_files = info[:,1]  # sample rates

print(f"Minimum: {dur_files.min():0.3f}, Maximum: {dur_files.max():0.3f}, Average: {dur_files.mean():0.3f}")
print(f"Minimum: {sr_files.min():0.3f}, Maximum: {sr_files.max():0.3f}, Average: {sr_files.mean():0.3f}")
# Out:
# Minimum: 0.729, Maximum: 11.129, Average: 3.392
# Minimum: 22050.000, Maximum: 22050.000, Average: 22050.000

# %% [markdown]
# The minimum duration is 0.7 seconds and the maximum is 11 seconds

# %%
# plot a histogram of the durations
plt.hist(dur_files, 30)
plt.ylabel("Count")
plt.xlabel("Duration [s]")
plt.show()

# %% [markdown]
# I think here there are roughly 200 files which has a duration less than 2 seconds. Let's select files which has a duration greater than 2 seconds. Then will take the first 2 seconds of data for training. Let's add this information to the final dataframe as well

# %%
# adding the duration and sample rate to the fin_df
fin_df.insert(2, 'duration', dur_files)
fin_df.insert(3, 'sample_rate', sr_files)

# %%
# converting labels to numerical values
fin_df['label'] = fin_df['label'].replace({'bonafide' : 1 , 'spoof' : 0})

# look at the header after adding new columns
fin_df.head()
# Out:
#                                                 filename  label  duration  \
# 2387   /Users/savin/Omdena-Projects/Audioshield/data_...      1  7.783583
# 12595  /Users/savin/Omdena-Projects/Audioshield/data_...      0  4.000454
# 654    /Users/savin/Omdena-Projects/Audioshield/data_...      1  7.378730
# 1084   /Users/savin/Omdena-Projects/Audioshield/data_...      1  2.679501
# 2516   /Users/savin/Omdena-Projects/Audioshield/data_...      1  2.128073
#
#        sample_rate
# 2387       22050.0
# 12595      22050.0
# 654        22050.0
# 1084       22050.0
# 2516       22050.0

# %%
# Let's select files which has a minimum duration of 2 seconds
df_cut = fin_df[fin_df['duration']>=2.0]

df_cut.head()
#df_cut.describe()
# Out:
#                                                 filename  label  duration  \
# 2387   /Users/savin/Omdena-Projects/Audioshield/data_...      1  7.783583
# 12595  /Users/savin/Omdena-Projects/Audioshield/data_...      0  4.000454
# 654    /Users/savin/Omdena-Projects/Audioshield/data_...      1  7.378730
# 1084   /Users/savin/Omdena-Projects/Audioshield/data_...      1  2.679501
# 2516   /Users/savin/Omdena-Projects/Audioshield/data_...      1  2.128073
#
#        sample_rate
# 2387       22050.0
# 12595      22050.0
# 654        22050.0
# 1084       22050.0
# 2516       22050.0

# %% [markdown]
# We lost around 686 samples in the duration threshold cut process.

# %% [markdown]
# ####  Splitting of the data
# Now this dataframe will be split into train and cross vaildation with a 80:20 ratio. After that we will load 2 seconds of data from each audio file, convert it into a mel spectrogram and store it as an array.

# %%
from sklearn.model_selection import train_test_split

# Split into train and test first
df_train, df_cv = train_test_split(df_cut, test_size = 0.2, random_state = 0)

print(f" Train set size: {df_train.shape[0]}, CV set size: {df_cv.shape[0]}")
# Out:
#  Train set size: 3736, CV set size: 935

# %%
# Grid size of Mel spectrogram for reading 2 seconds of data
ntime = 87
nfreq = 128

# Initializing the array to save the mel spectrograms
X_train = np.zeros((df_train.shape[0], nfreq, ntime, 1))
Y_train = df_train['label']

X_cv = np.zeros((df_cv.shape[0], nfreq, ntime, 1))
Y_cv = df_cv['label']

# Now let's load the load first 2 seconds of the audio files into the train and CV data
def load_mel(df, data):
    """
    Load audio file, extract spectrogram and store them in a numpy array
    Returns spectrogram matrix
    arguments:
    df: data frame containing file info
    data : data array, numpy array
    """
    for i in range(df.shape[0]):
        ydat, samp_rate = librosa.load(df.iloc[i,0])
        # inputing only 2 seconds of time series for spectrogram extraction
        S_mel = librosa.feature.melspectrogram(y=ydat[:int(samp_rate*2.0)], sr=samp_rate, n_mels=128)
        S_mel_db = librosa.amplitude_to_db(S_mel, ref=np.max)
        # Min max normalizing before loading the dataset
        data[i,:,:, 0] = (S_mel_db - S_mel_db.min())/(S_mel_db.max() - S_mel_db.min())

# %%
# Load mel spectrograms
load_mel(df_train, X_train)
load_mel(df_cv, X_cv)

# %%
# Now let's plot the some of the first real and fake data
fig, axs = plt.subplots(4,4, constrained_layout=True, figsize = (12,12))
for i in range(4):
    for j in range(4):
        num = i*4+j
        img = X_train[num,:,:, 0]
        axs[i,j].pcolormesh(img)
        axs[i,j].set_title(f"Class: {Y_train.iloc[num]}")
plt.show()

# %% [markdown]
# The data has been loaded into the X_train and X_cv arrays. Now let's do the modeling of the data.

# %% [markdown]
# ### Modeling the data
# For modeling the data, we will try to use different variants of the convolutional neural network (CNN), First we will start with a simpler CNN model and see how the network trains the data.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, BatchNormalization, Input

input_shape = X_train.shape[1:]
# Let's build a CNN model of this form
# Input >> ConV2D << Maxpool << Conv2D <<  Maxpool <<  ConV2D << Maxpool << Conv2D << Maxpool << Flatten << Dense << Dense << Dense (sigmoid)
simple_cnn = Sequential([
    Input(shape=input_shape),
    Conv2D(filters=32, kernel_size=3, strides=(1,1), activation='relu', padding='valid', name = 'conv1'), 
    MaxPool2D(pool_size=(4, 4), strides=(2,2), name = 'pool1'),
    Conv2D(filters=64, kernel_size=3, strides=(1,1), activation='relu', padding='valid', name = 'conv2'), 
    MaxPool2D(pool_size=(3, 3), strides=(2,3), name = 'pool2'),
    Conv2D(filters=128, kernel_size=5, strides=(1,1), activation='relu', padding='valid', name = 'conv3'),
    MaxPool2D(pool_size=(2, 2), strides=(2,2), name = 'pool3'),
    Conv2D(filters=256, kernel_size=3, strides=(1,1), activation='relu', padding='valid', name = 'conv4'),          
    MaxPool2D(pool_size=(2, 2), strides=(2,2), name = 'pool4'),
    Flatten(name = 'Flat'),
    Dense(128, activation='relu', name='Dense1'),
    Dense(16, activation='relu', name='Dense2'),
    Dense(1, activation='sigmoid', name='output' )])

simple_cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
simple_cnn.summary()
# Out:
# 2024-07-17 19:33:56.279790: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 126, 85, 32)       320
#
#  pool1 (MaxPooling2D)        (None, 62, 41, 32)        0
#
#  conv2 (Conv2D)              (None, 60, 39, 64)        18496
#
#  pool2 (MaxPooling2D)        (None, 29, 13, 64)        0
#
#  conv3 (Conv2D)              (None, 25, 9, 128)        204928
#
#  pool3 (MaxPooling2D)        (None, 12, 4, 128)        0
#
#  conv4 (Conv2D)              (None, 10, 2, 256)        295168
#
#  pool4 (MaxPooling2D)        (None, 5, 1, 256)         0
#
#  Flat (Flatten)              (None, 1280)              0
#
#  Dense1 (Dense)              (None, 128)               163968
#
#  Dense2 (Dense)              (None, 16)                2064
#
#  output (Dense)              (None, 1)                 17
#
# =================================================================
# Total params: 684,961
# Trainable params: 684,961
# Non-trainable params: 0
# _________________________________________________________________
# 2024-07-17 19:33:58.708732: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Let's train the model now
history = simple_cnn.fit(X_train, Y_train, epochs=25, batch_size=64, validation_data=(X_cv, Y_cv))
# Out:
# Epoch 1/25
# 59/59 [==============================] - 14s 230ms/step - loss: 0.5662 - accuracy: 0.6882 - val_loss: 0.5068 - val_accuracy: 0.7348
# Epoch 2/25
# 59/59 [==============================] - 14s 241ms/step - loss: 0.5026 - accuracy: 0.7350 - val_loss: 0.4763 - val_accuracy: 0.7658
# Epoch 3/25
# 59/59 [==============================] - 14s 242ms/step - loss: 0.4388 - accuracy: 0.7891 - val_loss: 0.3775 - val_accuracy: 0.8310
# Epoch 4/25
# 59/59 [==============================] - 13s 229ms/step - loss: 0.3043 - accuracy: 0.8678 - val_loss: 0.2908 - val_accuracy: 0.8856
# Epoch 5/25
# 59/59 [==============================] - 13s 222ms/step - loss: 0.2292 - accuracy: 0.9039 - val_loss: 0.2897 - val_accuracy: 0.8845
# Epoch 6/25
# 59/59 [==============================] - 13s 223ms/step - loss: 0.1854 - accuracy: 0.9221 - val_loss: 0.2559 - val_accuracy: 0.8973
# Epoch 7/25
# 59/59 [==============================] - 14s 235ms/step - loss: 0.1462 - accuracy: 0.9433 - val_loss: 0.2638 - val_accuracy: 0.9037
# Epoch 8/25
# 59/59 [==============================] - 14s 237ms/step - loss: 0.1087 - accuracy: 0.9553 - val_loss: 0.2588 - val_accuracy: 0.8995
# Epoch 9/25
# 59/59 [==============================] - 13s 225ms/step - loss: 0.0819 - accuracy: 0.9708 - val_loss: 0.2154 - val_accuracy: 0.9155
# Epoch 10/25
# 59/59 [==============================] - 13s 224ms/step - loss: 0.0600 - accuracy: 0.9764 - val_loss: 0.3396 - val_accuracy: 0.9048
# Epoch 11/25
# 59/59 [==============================] - 13s 228ms/step - loss: 0.0588 - accuracy: 0.9762 - val_loss: 0.3070 - val_accuracy: 0.9091
# Epoch 12/25
# 59/59 [==============================] - 13s 224ms/step - loss: 0.0421 - accuracy: 0.9845 - val_loss: 0.3587 - val_accuracy: 0.9102
# Epoch 13/25
# 59/59 [==============================] - 13s 225ms/step - loss: 0.0360 - accuracy: 0.9845 - val_loss: 0.4911 - val_accuracy: 0.8973
# Epoch 14/25
# 59/59 [==============================] - 13s 228ms/step - loss: 0.0300 - accuracy: 0.9872 - val_loss: 0.3624 - val_accuracy: 0.9102
# Epoch 15/25
# 59/59 [==============================] - 13s 225ms/step - loss: 0.0337 - accuracy: 0.9847 - val_loss: 0.5466 - val_accuracy: 0.8973
# Epoch 16/25
# 59/59 [==============================] - 14s 231ms/step - loss: 0.0784 - accuracy: 0.9692 - val_loss: 0.2999 - val_accuracy: 0.9176
# Epoch 17/25
# 59/59 [==============================] - 15s 255ms/step - loss: 0.0339 - accuracy: 0.9861 - val_loss: 0.3883 - val_accuracy: 0.9091
# Epoch 18/25
# 59/59 [==============================] - 15s 256ms/step - loss: 0.0228 - accuracy: 0.9896 - val_loss: 0.3881 - val_accuracy: 0.9251
# Epoch 19/25
# 59/59 [==============================] - 14s 234ms/step - loss: 0.0229 - accuracy: 0.9914 - val_loss: 0.3513 - val_accuracy: 0.9123
# Epoch 20/25
# 59/59 [==============================] - 13s 226ms/step - loss: 0.0173 - accuracy: 0.9928 - val_loss: 0.4172 - val_accuracy: 0.9123
# Epoch 21/25
# 59/59 [==============================] - 14s 232ms/step - loss: 0.0257 - accuracy: 0.9904 - val_loss: 0.4026 - val_accuracy: 0.9112
# Epoch 22/25
# 59/59 [==============================] - 14s 240ms/step - loss: 0.0270 - accuracy: 0.9898 - val_loss: 0.6158 - val_accuracy: 0.9016
# Epoch 23/25
# 59/59 [==============================] - 13s 226ms/step - loss: 0.0346 - accuracy: 0.9869 - val_loss: 0.3642 - val_accuracy: 0.9134
# Epoch 24/25
# 59/59 [==============================] - 13s 229ms/step - loss: 0.0212 - accuracy: 0.9893 - val_loss: 0.3964 - val_accuracy: 0.9102
# Epoch 25/25
# 59/59 [==============================] - 13s 228ms/step - loss: 0.0155 - accuracy: 0.9917 - val_loss: 0.5109 - val_accuracy: 0.9144

# %% [markdown]
# That's pretty good. The history dictionary has the loss and accuray of the model on the training and validation data. Let's convert these dictionaries into a pandas data frame and plot them up.

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(history.history)

# losses data frame
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)

# accuracy data frame
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)

# plotting the loss and accuracy
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# /var/folders/c8/g5hp4hlx7dv6gv7n9zdg74rc0000gn/T/ipykernel_45509/3697081374.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# /var/folders/c8/g5hp4hlx7dv6gv7n9zdg74rc0000gn/T/ipykernel_45509/3697081374.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]

# %%
ycv = simple_cnn.predict(np.expand_dims(X_cv[100,:,:,:],0))
print(ycv)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [[0.99993825]]

# %%
print(ycv[0])
# Out:
# [1.]

# %%
# Let's save the model to an h5 format
simple_cnn.save("simple-cnn-ssv.h5")
